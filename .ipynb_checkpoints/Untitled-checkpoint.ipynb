# %%
from pymongo import MongoClient

mongo_client = MongoClient()
db = mongo_client['uvi_corpora']

# %%
db.verbnet.find_one()
# Out:
# {'_id': ObjectId('5b8df75fc1c2b78c30718f5b'),
#  'class_id': 'attend-107.4',
#  'num_comparison_id': 107.4,
#  'members': [],
#  'themroles': [{'themrole': 'Theme',
#    'selrestrs': {'selrestrs_list': None, 'selrestr_logic': '&'},
#    'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}},
#   {'themrole': 'Goal',
#    'selrestrs': {'selrestrs_list': None, 'selrestr_logic': '&'},
#    'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}],
#  'frames': [],
#  'subclasses': [{'class_id': 'attend-107.4-1',
#    'num_comparison_id': 107.41,
#    'members': [{'name': 'attend',
#      'wn': ['attend%2:42:00'],
#      'grouping': ['attend.01'],
#      'vs_features': None},
#     {'name': 'patronize',
#      'wn': ['patronize%2:32:00'],
#      'grouping': ['patronize.01'],
#      'vs_features': None}],
#    'themroles': [],
#    'frames': [{'description': {'primary': 'NP V NP',
#       'secondary': 'Transitive',
#       'number': '8.1',
#       'xtag': ''},
# ...
