# %%
from pymongo import MongoClient

mongo_client = MongoClient()
db = mongo_client['uvi_corpora']

# %%
from collections import OrderedDict

# %%
themroles = []
themrole_count_dict = OrderedDict()
for themrole_list in db.verbnet.find({}, {'themroles.themrole':1, '_id':0}):
    themroles.extend([themrole['themrole'] for themrole in themrole_list['themroles']])
# themroles_set = set(themroles)
for themrole in sorted(themroles):
    themrole_count_dict[themrole] = themrole_count_dict.get(themrole, 0) + 1
themrole_count_dict
# Out:
# OrderedDict([('Affector', 1),
#              ('Agent', 253),
#              ('Asset', 9),
#              ('Attribute', 26),
#              ('Beneficiary', 20),
#              ('Causer', 11),
#              ('Co-Agent', 16),
#              ('Co-Patient', 11),
#              ('Co-Theme', 12),
#              ('Context', 1),
#              ('Destination', 40),
#              ('Duration', 1),
#              ('Experiencer', 22),
#              ('Extent', 2),
#              ('Final_Time', 1),
#              ('Goal', 22),
#              ('Initial_Location', 23),
#              ('Initial_State', 3),
#              ('Instrument', 29),
#              ('Location', 36),
#              ('Manner', 1),
#              ('Material', 4),
#              ('Path', 1),
#              ('Patient', 79),
#              ('Pivot', 8),
#              ('Precondition', 1),
#              ('Predicate', 10),
#              ('Product', 5),
#              ('Recipient', 28),
#              ('Reflexive', 1),
#              ('Result', 32),
#              ('Source', 34),
#              ('Stimulus', 20),
#              ('Theme', 199),
#              ('Time', 1),
#              ('Topic', 22),
#              ('Trajectory', 10),
#              ('Value', 5)])

# %%
themroles_dict = OrderedDict()
import json
with open('themrole_defs.json') as td:
    themrole_defs = json.load(td)

for themrole_list in db.verbnet.find({}, {'themroles.themrole':1, 'class_id':1, '_id':0}):
    for tr in themrole_list['themroles']:
        if tr['themrole'] not in themroles_dict:
            themroles_dict[tr['themrole']] = {'count':1, 'vn_class_members':set([themrole_list['class_id']])}
            role_index = next((index for (index, d) in enumerate(themrole_defs) if d["name"] == "Patient"), None)
            themroles_dict[tr['themrole']]['description'] = themrole_defs[role_index]['description']
            themroles_dict[tr['themrole']]['example'] = themrole_defs[role_index]['example']            
        else:
            themroles_dict[tr['themrole']]['count']+=1
            themroles_dict[tr['themrole']]['vn_class_members'].add(themrole_list['class_id'])

themroles_dict
# Out:
# OrderedDict([('Agent',
#               {'count': 253,
#                'vn_class_members': {'accept-77.1',
#                 'accompany-51.7',
#                 'acquiesce-95.1',
#                 'act-114',
#                 'addict-96',
#                 'adjust-26.9',
#                 'admit-64.3',
#                 'adopt-93',
#                 'advise-37.9',
#                 'allow-64.1',
#                 'amalgamate-22.2',
#                 'amalgamate-22.2-2',
#                 'amalgamate-22.2-3-1-1',
#                 'amalgamate-22.2-3-2',
#                 'animal_sounds-38',
#                 'appoint-29.1',
#                 'assessment-34.1',
#                 'assuming_position-50',
#                 'avoid-52',
#                 'banish-10.2',
#                 'base-97.1',
#                 'battle-36.4',
#                 'beg-58.2',
#                 'begin-55.1',
#                 'being_dressed-41.3.3',
#                 'bend-45.2',
#                 'berry-13.7',
#                 'bill-54.5',
#                 'birth-28.2',
#                 'body_internal_motion-49.1',
#                 'body_motion-49.2',
#                 'braid-41.2.2',
#                 'break-45.1',
#                 'breathe-40.1.2',
#                 'bring-11.3',
#                 'build-26.1',
#                 'bully-59.5',
#                 'butter-9.9',
#                 'calve-28.1',
#                 'captain-29.8',
#                 'caring-75.2',
#                 'carry-11.4',
#                 'carve-21.2',
#                 'characterize-29.2',
#                 'chase-51.6',
#                 'cheat-10.6.1',
#                 'chew-39.2',
#                 'chit_chat-37.6',
#                 'classify-29.10',
#                 'clear-10.3',
#                 'coil-9.6',
#                 'coloring-24',
#                 'compel-59.1',
#                 'complain-37.8',
#                 'complete-55.2',
#                 'concealment-16',
#                 'conduct-111.1',
#                 'confess-37.10',
#                 'confine-92',
#                 'confront-98',
#                 'conjecture-29.5',
#                 'consider-29.9',
#                 'conspire-71',
#                 'consume-66',
#                 'continue-55.3',
#                 'contribute-13.2',
#                 'convert-26.6.2-1-1',
#                 'cooking-45.3',
#                 'cooperate-73.1',
#                 'cope-83',
#                 'correlate-86.1',
#                 'correspond-36.1.1',
#                 'crane-40.3.2',
#                 'create-26.4',
#                 'curtsey-40.3.3',
#                 'cut-21.1',
#                 'debone-10.8',
#                 'declare-29.4',
#                 'dedicate-79',
#                 'deduce-97.2',
#                 'defend-72.3',
#                 'deprive-10.6.2',
#                 'destroy-44',
#                 'devour-39.4',
#                 'dine-39.5',
#                 'disassemble-23.3',
#                 'discover-84',
#                 'distinguish-23.5',
#                 'dress-41.1.1',
#                 'dressing_well-41.3.2',
#                 'drive-11.5',
#                 'dub-29.3',
#                 'eat-39.1',
#                 'employment-95.3',
#                 'enforce-63',
#                 'equip-13.4.2',
#                 'establish-55.5',
#                 'estimate-34.2',
#                 'exchange-13.6.1',
#                 'exclude-107.3',
#                 'feeding-39.7',
#                 'ferret-35.6',
#                 'fill-9.8',
#                 'fire-10.10',
#                 'fit-54.3',
#                 'floss-41.2.1',
#                 'focus-87.1',
#                 'forbid-64.4',
#                 'fulfilling-13.4.1',
#                 'fulfilling-13.4.1-2',
#                 'funnel-9.3',
#                 'future_having-13.3',
#                 'get-13.5.1',
#                 'give-13.1',
#                 'gobble-39.3',
#                 'gorge-39.6',
#                 'groom-41.1.2',
#                 'grow-26.2.1',
#                 'help-72.1',
#                 'herd-47.5.2',
#                 'hiccup-40.1.1',
#                 'hire-13.5.3',
#                 'hit-18.1',
#                 'hold-15.1',
#                 'hunt-35.1',
#                 'illustrate-25.3',
#                 'image_impression-25.1',
#                 'initiate_communication-37.4.2',
#                 'inquire-37.1.2',
#                 'instr_communication-37.4.1',
#                 'intend-61.2',
#                 'interact-36.6',
#                 'interrogate-37.1.3',
#                 'invest-13.5.4',
#                 'investigate-35.4',
#                 'involve-107.1',
#                 'judgment-33.1',
#                 'keep-15.2',
#                 'knead-26.5',
#                 'learn-14',
#                 'lecture-37.11',
#                 'let-64.2',
#                 'light_emission-43.1',
#                 'linger-53.1',
#                 'lure-59.3',
#                 'manner_speaking-37.3',
#                 'marry-36.2',
#                 'masquerade-29.6',
#                 'meet-36.3',
#                 'mine-10.9',
#                 'mix-22.1',
#                 'modes_of_being_with_motion-47.3',
#                 'multiply-108',
#                 'murder-42.1',
#                 'neglect-75.1',
#                 'nonvehicle-51.4.2',
#                 'nonverbal_expression-40.2',
#                 'obtain-13.5.2',
#                 'order-58.3',
#                 'orphan-29.7',
#                 'other_cos-45.4',
#                 'overstate-37.12',
#                 'patent-101',
#                 'pay-68',
#                 'peer-30.3',
#                 'pelt-17.2',
#                 'performance-26.7',
#                 'pit-10.7',
#                 'pocket-9.10',
#                 'poison-42.2',
#                 'poke-19',
#                 'pour-9.5',
#                 'preparing-26.3',
#                 'price-54.4',
#                 'promise-37.13',
#                 'promote-102',
#                 'pronounce-29.3.1',
#                 'prosecute-33.2',
#                 'push-12',
#                 'put-9.1',
#                 'put_direction-9.4',
#                 'put_spatial-9.2',
#                 'rear-26.2.2',
#                 'reciprocate-112',
#                 'reflexive_appearance-48.1.2',
#                 'refrain-69',
#                 'register-54.1-1',
#                 'rehearse-26.8',
#                 'reject-77.2',
#                 'rely-70',
#                 'remedy-45.7',
#                 'remove-10.1',
#                 'resign-10.11',
#                 'respond-113',
#                 'risk-94',
#                 'rob-10.6.4',
#                 'roll-51.3.1',
#                 'rummage-35.5',
#                 'run-51.3.2-2',
#                 'rush-53.2',
#                 'satisfy-55.7',
#                 'say-37.7',
#                 'scribble-25.2',
#                 'search-35.2',
#                 'send-11.1',
#                 'separate-23.1',
#                 'settle-36.1.2',
#                 'shake-22.3',
#                 'simple_dressing-41.3.1',
#                 'slide-11.2',
#                 'snooze-40.4',
#                 'sound_emission-43.2',
#                 'spank-18.3',
#                 'spatial_configuration-47.6-1',
#                 'spend_time-104',
#                 'split-23.2',
#                 'spray-9.7',
#                 'stalk-35.3',
#                 'steal-10.5',
#                 'stimulate-59.4',
#                 'subjugate-42.3',
#                 'subordinate-95.2.1',
#                 'substance_emission-43.4-1-1',
#                 'succeed-74',
#                 'suffocate-40.7',
#                 'supervision-95.2.2',
#                 'support-15.3',
#                 'suspect-81',
#                 'sustain-55.6',
#                 'swat-18.2',
#                 'talk-37.5',
#                 'tape-22.4',
#                 'tell-37.2',
#                 'throw-17.1',
#                 'touch-20',
#                 'transcribe-25.4',
#                 'transfer_mesg-37.1.1',
#                 'trick-59.2',
#                 'trifle-105.3',
#                 'try-61.1',
#                 'turn-26.6.1',
#                 'urge-58.1',
#                 'use-105.1',
#                 'vehicle-51.4.1',
#                 'vehicle_path-51.4.3',
#                 'void-106',
#                 'volunteer-95.4',
#                 'waltz-51.5',
#                 'wink-40.3.1',
#                 'wipe_instr-10.4.2',
#                 'wipe_manner-10.4.1',
#                 'withdraw-82',
#                 'work-73.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Patient',
#               {'count': 79,
#                'vn_class_members': {'addict-96',
#                 'adjust-26.9',
#                 'amalgamate-22.2',
#                 'amalgamate-22.2-1',
#                 'amalgamate-22.2-2',
#                 'amalgamate-22.2-3-1-1',
#                 'amalgamate-22.2-3-2',
#                 'become-109.1',
#                 'beg-58.2',
#                 'bend-45.2',
#                 'birth-28.2',
#                 'body_internal_motion-49.1',
#                 'braid-41.2.2',
#                 'break-45.1',
#                 'break_down-45.8',
#                 'bully-59.5',
#                 'calibratable_cos-45.6.1',
#                 'calve-28.1',
#                 'carve-21.2',
#                 'caused_calibratable_cos-45.6.2',
#                 'chew-39.2',
#                 'chew-39.2-1',
#                 'chew-39.2-2',
#                 'coloring-24',
#                 'compel-59.1',
#                 'concealment-16',
#                 'convert-26.6.2',
#                 'cooking-45.3',
#                 'crane-40.3.2',
#                 'cut-21.1',
#                 'cut-21.1-1',
#                 'destroy-44',
#                 'devour-39.4',
#                 'die-42.4',
#                 'dine-39.5',
#                 'disappearance-48.2',
#                 'disassemble-23.3',
#                 'dress-41.1.1',
#                 'dressing_well-41.3.2',
#                 'eat-39.1-1',
#                 'eat-39.1-2',
#                 'eat-39.1-3',
#                 'entity_specific_cos-45.5',
#                 'floss-41.2.1',
#                 'gobble-39.3-1',
#                 'gobble-39.3-2',
#                 'gorge-39.6',
#                 'groom-41.1.2',
#                 'grow-26.2.1',
#                 'hit-18.1',
#                 'hurt-40.8.3-1',
#                 'limit-76',
#                 'lure-59.3',
#                 'mix-22.1',
#                 'murder-42.1',
#                 'order-58.3',
#                 'other_cos-45.4',
#                 'pain-40.8.1',
#                 'poison-42.2',
#                 'poke-19',
#                 'preparing-26.3-2',
#                 'prosecute-33.2',
#                 'remedy-45.7',
#                 'render-29.90',
#                 'separate-23.1',
#                 'shake-22.3',
#                 'spank-18.3',
#                 'split-23.2',
#                 'stimulate-59.4',
#                 'subjugate-42.3',
#                 'suffocate-40.7',
#                 'swat-18.2',
#                 'tape-22.4',
#                 'tingle-40.8.2',
#                 'trick-59.2',
#                 'turn-26.6.1',
#                 'urge-58.1',
#                 'void-106',
#                 'wink-40.3.1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Result',
#               {'count': 32,
#                'vn_class_members': {'amuse-31.1',
#                 'appoint-29.1',
#                 'become-109.1',
#                 'beg-58.2',
#                 'bend-45.2',
#                 'break-45.1',
#                 'bully-59.5',
#                 'calibratable_cos-45.6.1-1',
#                 'coloring-24',
#                 'convert-26.6.2',
#                 'cooking-45.3',
#                 'create-26.4',
#                 'cut-21.1',
#                 'declare-29.4',
#                 'dub-29.3',
#                 'hit-18.1',
#                 'order-58.3',
#                 'other_cos-45.4',
#                 'poison-42.2',
#                 'push-12',
#                 'render-29.90',
#                 'roll-51.3.1',
#                 'run-51.3.2-2',
#                 'spank-18.3',
#                 'suffocate-40.7',
#                 'swat-18.2',
#                 'tape-22.4',
#                 'throw-17.1',
#                 'turn-26.6.1',
#                 'urge-58.1',
#                 'vehicle-51.4.1',
#                 'wipe_instr-10.4.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Theme',
#               {'count': 199,
#                'vn_class_members': {'absorb-39.8',
#                 'accept-77.1',
#                 'accompany-51.7',
#                 'acquiesce-95.1',
#                 'admit-64.3',
#                 'adopt-93',
#                 'allow-64.1',
#                 'animal_sounds-38',
#                 'appear-48.1.1',
#                 'appoint-29.1',
#                 'assessment-34.1',
#                 'attend-107.4',
#                 'avoid-52',
#                 'banish-10.2',
#                 'base-97.1',
#                 'battle-36.4',
#                 'begin-55.1',
#                 'being_dressed-41.3.3',
#                 'body_motion-49.2',
#                 'breathe-40.1.2',
#                 'bring-11.3',
#                 'bulge-47.5.3',
#                 'bump-18.4',
#                 'butter-9.9',
#                 'caring-75.2',
#                 'carry-11.4',
#                 'characterize-29.2',
#                 'chase-51.6',
#                 'cheat-10.6.1',
#                 'classify-29.10',
#                 'clear-10.3',
#                 'cling-22.5',
#                 'coil-9.6',
#                 'complete-55.2',
#                 'comprise-107.2',
#                 'conduct-111.1',
#                 'confine-92',
#                 'confront-98',
#                 'conjecture-29.5',
#                 'consider-29.9',
#                 'conspire-71',
#                 'contain-15.4',
#                 'contiguous_location-47.8',
#                 'continue-55.3',
#                 'contribute-13.2',
#                 'cooperate-73.1',
#                 'cope-83',
#                 'correlate-86.1',
#                 'cost-54.2',
#                 'debone-10.8',
#                 'declare-29.4',
#                 'dedicate-79',
#                 'deduce-97.2',
#                 'defend-72.3',
#                 'deprive-10.6.2',
#                 'differ-23.4',
#                 'discover-84',
#                 'disfunction-105.2.2',
#                 'distinguish-23.5',
#                 'drive-11.5',
#                 'dub-29.3',
#                 'earn-54.6',
#                 'employment-95.3',
#                 'enforce-63',
#                 'engender-27.1',
#                 'ensure-99',
#                 'entity_specific_modes_being-47.2',
#                 'equip-13.4.2',
#                 'escape-51.1',
#                 'establish-55.5',
#                 'estimate-34.2',
#                 'exceed-90',
#                 'exchange-13.6.1',
#                 'exclude-107.3',
#                 'exhale-40.1.3',
#                 'exist-47.1',
#                 'feeding-39.7',
#                 'ferret-35.6',
#                 'fill-9.8',
#                 'fire-10.10',
#                 'forbid-64.4',
#                 'free-10.6.3',
#                 'free-80',
#                 'fulfilling-13.4.1',
#                 'function-105.2.1',
#                 'funnel-9.3',
#                 'future_having-13.3',
#                 'get-13.5.1',
#                 'give-13.1',
#                 'harmonize-22.6',
#                 'help-72.1',
#                 'herd-47.5.2',
#                 'hire-13.5.3',
#                 'hold-15.1',
#                 'hunt-35.1',
#                 'illustrate-25.3',
#                 'image_impression-25.1',
#                 'invest-13.5.4',
#                 'investigate-35.4',
#                 'involve-107.1',
#                 'judgment-33.1',
#                 'keep-15.2',
#                 'leave-51.2',
#                 'let-64.2',
#                 'light_emission-43.1',
#                 'linger-53.1',
#                 'lodge-46',
#                 'long-32.2',
#                 'meander-47.7',
#                 'mine-10.9',
#                 'modes_of_being_with_motion-47.3',
#                 'multiply-108',
#                 'neglect-75.1',
#                 'nonvehicle-51.4.2',
#                 'nonverbal_expression-40.2',
#                 'obtain-13.5.2',
#                 'occur-48.3',
#                 'orphan-29.7',
#                 'overstate-37.12',
#                 'own-100.1',
#                 'patent-101',
#                 'pay-68',
#                 'peer-30.3',
#                 'pelt-17.2',
#                 'performance-26.7',
#                 'pit-10.7',
#                 'pocket-9.10',
#                 'pour-9.5',
#                 'price-54.4',
#                 'promote-102',
#                 'pronounce-29.3.1',
#                 'prosecute-33.2',
#                 'push-12',
#                 'put-9.1',
#                 'put-9.1-2',
#                 'put_direction-9.4',
#                 'put_spatial-9.2',
#                 'reach-51.8',
#                 'reciprocate-112',
#                 'reflexive_appearance-48.1.2',
#                 'refrain-69',
#                 'register-54.1',
#                 'rehearse-26.8',
#                 'reject-77.2',
#                 'relate-86.2',
#                 'rely-70',
#                 'remove-10.1',
#                 'representation-110.1',
#                 'require-103',
#                 'respond-113',
#                 'result-27.2',
#                 'risk-94',
#                 'rob-10.6.4',
#                 'roll-51.3.1',
#                 'rummage-35.5',
#                 'run-51.3.2',
#                 'rush-53.2',
#                 'satisfy-55.7',
#                 'scribble-25.2',
#                 'search-35.2',
#                 'seem-109',
#                 'send-11.1',
#                 'simple_dressing-41.3.1',
#                 'slide-11.2',
#                 'smell_emission-43.3',
#                 'snooze-40.4-1',
#                 'sound_emission-43.2',
#                 'sound_existence-47.4',
#                 'spatial_configuration-47.6',
#                 'spray-9.7',
#                 'spray-9.7-1',
#                 'spray-9.7-2',
#                 'stalk-35.3',
#                 'steal-10.5',
#                 'stop-55.4',
#                 'substance_emission-43.4',
#                 'substitute-13.6.2',
#                 'succeed-74',
#                 'support-15.3',
#                 'suspect-81',
#                 'sustain-55.6',
#                 'swarm-47.5.1',
#                 'terminus-47.9',
#                 'throw-17.1',
#                 'transcribe-25.4',
#                 'trifle-105.3',
#                 'try-61.1',
#                 'use-105.1',
#                 'vehicle-51.4.1',
#                 'vehicle_path-51.4.3',
#                 'volunteer-95.4',
#                 'waltz-51.5',
#                 'want-32.1',
#                 'weather-57',
#                 'weekend-56',
#                 'wink-40.3.1',
#                 'wipe_instr-10.4.2',
#                 'wipe_manner-10.4.1',
#                 'work-73.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Attribute',
#               {'count': 26,
#                'vn_class_members': {'admire-31.2',
#                 'assessment-34.1',
#                 'calibratable_cos-45.6.1',
#                 'caused_calibratable_cos-45.6.2',
#                 'caused_calibratable_cos-45.6.2-1',
#                 'characterize-29.2',
#                 'comprehend-87.2',
#                 'comprise-107.2',
#                 'consider-29.9',
#                 'create-26.4',
#                 'employment-95.3',
#                 'exceed-90',
#                 'fire-10.10',
#                 'hire-13.5.3',
#                 'intend-61.2',
#                 'interrogate-37.1.3',
#                 'judgment-33.1',
#                 'masquerade-29.6',
#                 'pronounce-29.3.1',
#                 'prosecute-33.2-1',
#                 'register-54.1-1',
#                 'seem-109',
#                 'spend_time-104',
#                 'suspect-81',
#                 'sustain-55.6-1',
#                 'volunteer-95.4'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Location',
#               {'count': 36,
#                'vn_class_members': {'admit-64.3',
#                 'animal_sounds-38',
#                 'appear-48.1.1',
#                 'assuming_position-50',
#                 'avoid-52',
#                 'bulge-47.5.3',
#                 'bump-18.4',
#                 'concealment-16',
#                 'eat-39.1',
#                 'entity_specific_modes_being-47.2',
#                 'exist-47.1',
#                 'fit-54.3',
#                 'hunt-35.1',
#                 'investigate-35.4',
#                 'keep-15.2',
#                 'light_emission-43.1',
#                 'linger-53.1',
#                 'lodge-46',
#                 'meander-47.7',
#                 'modes_of_being_with_motion-47.3',
#                 'occur-48.3',
#                 'rummage-35.5',
#                 'search-35.2',
#                 'smell_emission-43.3',
#                 'sound_emission-43.2',
#                 'sound_existence-47.4',
#                 'spank-18.3',
#                 'spatial_configuration-47.6',
#                 'stalk-35.3',
#                 'substance_emission-43.4-1',
#                 'substitute-13.6.2',
#                 'swarm-47.5.1',
#                 'swat-18.2',
#                 'terminus-47.9',
#                 'vehicle-51.4.1-1',
#                 'weekend-56'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Destination',
#               {'count': 40,
#                'vn_class_members': {'accompany-51.7',
#                 'banish-10.2',
#                 'breathe-40.1.2',
#                 'bring-11.3',
#                 'bring-11.3-1',
#                 'butter-9.9',
#                 'carry-11.4',
#                 'carry-11.4-1-1',
#                 'clear-10.3',
#                 'coil-9.6',
#                 'confine-92',
#                 'debone-10.8',
#                 'drive-11.5',
#                 'escape-51.1',
#                 'fill-9.8',
#                 'funnel-9.3',
#                 'illustrate-25.3',
#                 'image_impression-25.1',
#                 'mine-10.9',
#                 'pelt-17.2',
#                 'pit-10.7',
#                 'pocket-9.10',
#                 'pour-9.5',
#                 'put-9.1',
#                 'put_direction-9.4',
#                 'put_spatial-9.2',
#                 'run-51.3.2',
#                 'scribble-25.2',
#                 'send-11.1',
#                 'send-11.1-1',
#                 'slide-11.2',
#                 'slide-11.2-1',
#                 'spray-9.7',
#                 'throw-17.1',
#                 'throw-17.1-1',
#                 'transcribe-25.4',
#                 'vehicle_path-51.4.3',
#                 'wipe_instr-10.4.2',
#                 'wipe_instr-10.4.2-1',
#                 'wipe_manner-10.4.1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Trajectory',
#               {'count': 10,
#                'vn_class_members': {'chase-51.6',
#                 'escape-51.1',
#                 'nonvehicle-51.4.2',
#                 'push-12',
#                 'roll-51.3.1',
#                 'run-51.3.2',
#                 'slide-11.2',
#                 'vehicle-51.4.1',
#                 'vehicle_path-51.4.3',
#                 'waltz-51.5'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Causer',
#               {'count': 11,
#                'vn_class_members': {'benefit-72.2',
#                 'caused_calibratable_cos-45.6.2',
#                 'die-42.4',
#                 'engender-27.1',
#                 'free-10.6.3',
#                 'free-80',
#                 'indicate-78',
#                 'limit-76',
#                 'render-29.90',
#                 'result-27.2',
#                 'throw-17.1-1-1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Source',
#               {'count': 34,
#                'vn_class_members': {'absorb-39.8',
#                 'adjust-26.9',
#                 'banish-10.2',
#                 'base-97.1',
#                 'caused_calibratable_cos-45.6.2',
#                 'cheat-10.6.1',
#                 'clear-10.3',
#                 'cut-21.1',
#                 'debone-10.8',
#                 'deduce-97.2',
#                 'deprive-10.6.2',
#                 'discover-84',
#                 'ferret-35.6',
#                 'fire-10.10',
#                 'free-10.6.3',
#                 'free-80',
#                 'get-13.5.1',
#                 'get-13.5.1-1',
#                 'learn-14',
#                 'leave-51.2',
#                 'obtain-13.5.2',
#                 'pit-10.7',
#                 'remove-10.1',
#                 'require-103-1',
#                 'resign-10.11',
#                 'rob-10.6.4',
#                 'run-51.3.2-2',
#                 'steal-10.5',
#                 'substance_emission-43.4',
#                 'substitute-13.6.2',
#                 'transfer_mesg-37.1.1',
#                 'wipe_manner-10.4.1',
#                 'wipe_manner-10.4.1-1',
#                 'withdraw-82'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Predicate',
#               {'count': 10,
#                'vn_class_members': {'act-114',
#                 'compel-59.1',
#                 'conjecture-29.5',
#                 'function-105.2.1-1',
#                 'lure-59.3',
#                 'reciprocate-112',
#                 'respond-113',
#                 'stimulate-59.4',
#                 'trick-59.2',
#                 'use-105.1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Co-Agent',
#               {'count': 16,
#                'vn_class_members': {'acquiesce-95.1',
#                 'battle-36.4',
#                 'chit_chat-37.6',
#                 'conspire-71',
#                 'cooperate-73.1',
#                 'correspond-36.1.1',
#                 'employment-95.3',
#                 'exchange-13.6.1',
#                 'interact-36.6',
#                 'marry-36.2',
#                 'meet-36.3',
#                 'settle-36.1.2',
#                 'subordinate-95.2.1',
#                 'supervision-95.2.2',
#                 'talk-37.5',
#                 'work-73.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Topic',
#               {'count': 22,
#                'vn_class_members': {'advise-37.9',
#                 'chit_chat-37.6',
#                 'complain-37.8',
#                 'confess-37.10',
#                 'correspond-36.1.1',
#                 'crane-40.3.2',
#                 'curtsey-40.3.3',
#                 'focus-87.1',
#                 'indicate-78',
#                 'inquire-37.1.2',
#                 'instr_communication-37.4.1',
#                 'intend-61.2',
#                 'interrogate-37.1.3',
#                 'learn-14',
#                 'lecture-37.11',
#                 'manner_speaking-37.3',
#                 'promise-37.13',
#                 'say-37.7',
#                 'settle-36.1.2',
#                 'talk-37.5',
#                 'tell-37.2',
#                 'transfer_mesg-37.1.1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Experiencer',
#               {'count': 22,
#                'vn_class_members': {'admire-31.2',
#                 'amuse-31.1',
#                 'appeal-31.4',
#                 'body_internal_states-40.6',
#                 'care-88.1',
#                 'change_bodily_state-40.8.4',
#                 'cognize-85',
#                 'comprehend-87.2',
#                 'empathize-88.2',
#                 'encounter-30.5',
#                 'flinch-40.5',
#                 'hurt-40.8.3',
#                 'marvel-31.3',
#                 'matter-91',
#                 'pain-40.8.1',
#                 'see-30.1',
#                 'sight-30.2',
#                 'stimulus_subject-30.4',
#                 'tingle-40.8.2',
#                 'touch-20',
#                 'touch-20-1',
#                 'wish-62'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Stimulus',
#               {'count': 20,
#                'vn_class_members': {'addict-96',
#                 'admire-31.2',
#                 'amuse-31.1',
#                 'appeal-31.4',
#                 'body_internal_states-40.6',
#                 'care-88.1',
#                 'change_bodily_state-40.8.4',
#                 'cognize-85',
#                 'comprehend-87.2',
#                 'empathize-88.2',
#                 'encounter-30.5',
#                 'flinch-40.5',
#                 'marvel-31.3',
#                 'matter-91',
#                 'pain-40.8.1',
#                 'see-30.1',
#                 'sight-30.2',
#                 'stimulus_subject-30.4',
#                 'tingle-40.8.2',
#                 'wish-62'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Recipient',
#               {'count': 28,
#                'vn_class_members': {'advise-37.9',
#                 'animal_sounds-38',
#                 'bill-54.5',
#                 'complain-37.8',
#                 'confess-37.10',
#                 'contribute-13.2',
#                 'crane-40.3.2',
#                 'curtsey-40.3.3',
#                 'equip-13.4.2',
#                 'feeding-39.7',
#                 'fulfilling-13.4.1',
#                 'fulfilling-13.4.1-2',
#                 'give-13.1',
#                 'indicate-78',
#                 'initiate_communication-37.4.2',
#                 'inquire-37.1.2',
#                 'instr_communication-37.4.1',
#                 'interrogate-37.1.3',
#                 'lecture-37.11',
#                 'manner_speaking-37.3',
#                 'nonverbal_expression-40.2',
#                 'pay-68-1',
#                 'promise-37.13',
#                 'reflexive_appearance-48.1.2',
#                 'say-37.7',
#                 'tell-37.2',
#                 'transfer_mesg-37.1.1',
#                 'wink-40.3.1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Co-Theme',
#               {'count': 12,
#                'vn_class_members': {'cling-22.5',
#                 'contiguous_location-47.8',
#                 'correlate-86.1',
#                 'differ-23.4',
#                 'distinguish-23.5',
#                 'exceed-90',
#                 'exchange-13.6.1',
#                 'harmonize-22.6',
#                 'multiply-108',
#                 'relate-86.2',
#                 'representation-110.1',
#                 'substitute-13.6.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Instrument',
#               {'count': 29,
#                'vn_class_members': {'begin-55.1',
#                 'bend-45.2',
#                 'break-45.1',
#                 'bring-11.3',
#                 'carve-21.2',
#                 'confront-98',
#                 'cooking-45.3',
#                 'cut-21.1',
#                 'destroy-44',
#                 'distinguish-23.5',
#                 'establish-55.5-1',
#                 'floss-41.2.1',
#                 'hit-18.1',
#                 'hit-18.1-1',
#                 'murder-42.1',
#                 'murder-42.1-1',
#                 'other_cos-45.4',
#                 'poison-42.2',
#                 'poke-19',
#                 'remedy-45.7',
#                 'satisfy-55.7',
#                 'spank-18.3',
#                 'subjugate-42.3',
#                 'support-15.3',
#                 'sustain-55.6',
#                 'swat-18.2',
#                 'tape-22.4',
#                 'touch-20',
#                 'wipe_instr-10.4.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Goal',
#               {'count': 22,
#                'vn_class_members': {'absorb-39.8',
#                 'adjust-26.9',
#                 'attend-107.4',
#                 'body_motion-49.2',
#                 'caused_calibratable_cos-45.6.2',
#                 'cheat-10.6.1',
#                 'classify-29.10',
#                 'consume-66',
#                 'dedicate-79',
#                 'deprive-10.6.2',
#                 'exclude-107.3',
#                 'fire-10.10',
#                 'future_having-13.3',
#                 'invest-13.5.4',
#                 'involve-107.1',
#                 'leave-51.2',
#                 'limit-76',
#                 'reach-51.8',
#                 'remove-10.1',
#                 'resign-10.11',
#                 'substitute-13.6.2',
#                 'waltz-51.5'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Co-Patient',
#               {'count': 11,
#                'vn_class_members': {'amalgamate-22.2',
#                 'amalgamate-22.2-1',
#                 'amalgamate-22.2-2',
#                 'amalgamate-22.2-3-1-1',
#                 'amalgamate-22.2-3-2',
#                 'disassemble-23.3',
#                 'mix-22.1',
#                 'separate-23.1',
#                 'shake-22.3',
#                 'split-23.2',
#                 'tape-22.4'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Initial_Location',
#               {'count': 23,
#                'vn_class_members': {'bring-11.3',
#                 'butter-9.9',
#                 'carry-11.4',
#                 'coil-9.6',
#                 'disappearance-48.2',
#                 'drive-11.5',
#                 'escape-51.1',
#                 'fill-9.8',
#                 'funnel-9.3',
#                 'mine-10.9',
#                 'pelt-17.2',
#                 'pocket-9.10',
#                 'pour-9.5',
#                 'put-9.1',
#                 'put_direction-9.4',
#                 'put_spatial-9.2',
#                 'run-51.3.2',
#                 'send-11.1',
#                 'slide-11.2',
#                 'spray-9.7',
#                 'throw-17.1',
#                 'vehicle_path-51.4.3',
#                 'wipe_instr-10.4.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Beneficiary',
#               {'count': 20,
#                'vn_class_members': {'allow-64.1',
#                 'benefit-72.2',
#                 'build-26.1',
#                 'captain-29.8',
#                 'concealment-16',
#                 'conduct-111.1',
#                 'conspire-71',
#                 'cost-54.2',
#                 'create-26.4',
#                 'defend-72.3',
#                 'ensure-99',
#                 'forbid-64.4',
#                 'future_having-13.3',
#                 'get-13.5.1',
#                 'help-72.1',
#                 'let-64.2',
#                 'performance-26.7',
#                 'preparing-26.3',
#                 'rob-10.6.4',
#                 'steal-10.5'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Product',
#               {'count': 5,
#                'vn_class_members': {'build-26.1',
#                 'grow-26.2.1',
#                 'knead-26.5',
#                 'preparing-26.3-1',
#                 'rear-26.2.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Value',
#               {'count': 5,
#                'vn_class_members': {'cost-54.2',
#                 'estimate-34.2',
#                 'fit-54.3',
#                 'price-54.4',
#                 'register-54.1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Pivot',
#               {'count': 8,
#                'vn_class_members': {'contain-15.4',
#                 'exhale-40.1.3',
#                 'exist-47.1-1',
#                 'long-32.2',
#                 'own-100.1',
#                 'require-103',
#                 'volunteer-95.4',
#                 'want-32.1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Reflexive',
#               {'count': 1,
#                'vn_class_members': {'reflexive_appearance-48.1.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Time',
#               {'count': 1,
#                'vn_class_members': {'sound_emission-43.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Asset',
#               {'count': 9,
#                'vn_class_members': {'bill-54.5',
#                 'build-26.1',
#                 'consume-66',
#                 'earn-54.6',
#                 'get-13.5.1',
#                 'give-13.1-1',
#                 'invest-13.5.4',
#                 'obtain-13.5.2-1',
#                 'pay-68'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Context',
#               {'count': 1,
#                'vn_class_members': {'representation-110.1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Initial_State',
#               {'count': 3,
#                'vn_class_members': {'calibratable_cos-45.6.1-1',
#                 'convert-26.6.2',
#                 'turn-26.6.1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Duration',
#               {'count': 1,
#                'vn_class_members': {'spend_time-104'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Path',
#               {'count': 1,
#                'vn_class_members': {'body_motion-49.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Material',
#               {'count': 4,
#                'vn_class_members': {'build-26.1',
#                 'create-26.4',
#                 'knead-26.5',
#                 'rear-26.2.2-1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Final_Time',
#               {'count': 1,
#                'vn_class_members': {'continue-55.3'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Precondition',
#               {'count': 1,
#                'vn_class_members': {'ensure-99'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Affector',
#               {'count': 1,
#                'vn_class_members': {'stop-55.4'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Extent',
#               {'count': 2,
#                'vn_class_members': {'calibratable_cos-45.6.1-1',
#                 'caused_calibratable_cos-45.6.2'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'}),
#              ('Manner',
#               {'count': 1,
#                'vn_class_members': {'exist-47.1-1'},
#                'description': 'Undergoer in an event that is usually structurally changed, for instance by experiencing a change of state, location or condition, is often acted upon by an agent, that is causally involved or directly affected by other participants, and exists independently of the event.',
#                'example': 'Brutus murdered JULIUS CAESAR.'})])

# %%
#Can't simply match on cases where vs_features is not None, so instead we match cases where the datatype is a list (mongodb array) 
vs_features = []
vs_features_count_dict = OrderedDict()
for doc in list(db.verbnet.find({'members.vs_features': {'$type': 'array'}}, {'members.vs_features':1, 'class_id':1, '_id':0})):
    for vs_features_dict in doc['members']:
        if vs_features_dict['vs_features'] is not None:
            for vs in vs_features_dict['vs_features']:
                if vs not in vs_features_count_dict:
                    vs_features_count_dict[vs]={'count':1,
                                                'vn_class_mem':set([doc['class_id']])}
                else:
                    vs_features_count_dict[vs]['count'] += 1
                    vs_features_count_dict[vs]['vn_class_mem'].add(doc['class_id'])
print(vs_features_count_dict)
# Out:
# OrderedDict([('+speed', {'count': 62, 'vn_class_mem': {'run-51.3.2-2', 'run-51.3.2-2-1', 'run-51.3.2', 'run-51.3.2-1'}}), ('+bodily_manner', {'count': 62, 'vn_class_mem': {'run-51.3.2-2', 'run-51.3.2-2-1', 'run-51.3.2', 'run-51.3.2-1'}}), ('+orientation', {'count': 17, 'vn_class_mem': {'run-51.3.2-2', 'run-51.3.2-2-1', 'run-51.3.2', 'run-51.3.2-1'}}), ('+attitude', {'count': 26, 'vn_class_mem': {'run-51.3.2-2', 'run-51.3.2', 'run-51.3.2-1'}}), ('+path_shape', {'count': 22, 'vn_class_mem': {'run-51.3.2-2', 'run-51.3.2', 'run-51.3.2-1'}}), ('+purpose', {'count': 20, 'vn_class_mem': {'run-51.3.2-2', 'run-51.3.2-2-1', 'run-51.3.2', 'run-51.3.2-1'}})])

# %%
predicates = []
predicate_count_dict = OrderedDict()
for doc in list(db.verbnet.find({}, {'frames.semantics.predicate':1, '_id':0})):
    for frame in doc['frames']:
        predicates_list = [predicate['predicate'] for predicate in frame['semantics']]
        predicates.extend(predicates_list)

for predicate in sorted(predicates):
    predicate_count_dict[predicate] = predicate_count_dict.get(predicate, 0) + 1
predicate_count_dict
# Out:
# OrderedDict([('Adv', 4),
#              ('about', 34),
#              ('act', 23),
#              ('adjust', 1),
#              ('admit', 3),
#              ('adopt', 1),
#              ('agree', 6),
#              ('alive', 14),
#              ('allow', 9),
#              ('apart', 16),
#              ('appear', 8),
#              ('apply_heat', 7),
#              ('apply_material', 3),
#              ('approve', 9),
#              ('assess', 12),
#              ('attached', 15),
#              ('attempt', 8),
#              ('attract', 3),
#              ('authority_relationship', 18),
#              ('avoid', 4),
#              ('base', 4),
#              ('begin', 9),
#              ('believe', 4),
#              ('benefit', 28),
#              ('body_motion', 18),
#              ('body_process', 12),
#              ('body_reflex', 4),
#              ('calculate', 4),
#              ('capacity', 2),
#              ('cause', 713),
#              ('change_value', 17),
#              ('characterize', 16),
#              ('charge', 5),
#              ('conclude', 4),
#              ('confined', 2),
#              ('conflict', 23),
#              ('confront', 2),
#              ('consider', 19),
#              ('conspire', 4),
#              ('contact', 144),
#              ('contain', 1),
#              ('continue', 9),
#              ('convert', 7),
#              ('cooked', 9),
#              ('cooperate', 13),
#              ('cope', 3),
#              ('correlate', 2),
#              ('cost', 12),
#              ('covered', 3),
#              ('created_image', 12),
#              ('declare', 23),
#              ('dedicate', 2),
#              ('defend', 4),
#              ('degradation_material_integrity', 70),
#              ('delay', 1),
#              ('depend', 5),
#              ('describe', 9),
#              ('designated', 11),
#              ('desire', 22),
#              ('destroyed', 3),
#              ('different', 6),
#              ('direction', 8),
#              ('disappear', 4),
#              ('discomfort', 10),
#              ('discover', 20),
#              ('do', 12),
#              ('earn', 1),
#              ('emit', 38),
#              ('emotional_state', 34),
#              ('end', 7),
#              ('enforce', 2),
#              ('ensure', 4),
#              ('equals', 401),
#              ('exceed', 2),
#              ('exert_force', 20),
#              ('exist', 113),
#              ('experience', 9),
#              ('express', 5),
#              ('filled_with', 2),
#              ('financial_interest_in', 3),
#              ('financial_relationship', 2),
#              ('flinch', 4),
#              ('free', 12),
#              ('function', 3),
#              ('give_birth', 1),
#              ('group', 3),
#              ('harmed', 16),
#              ('harmonize', 4),
#              ('has_possession', 6),
#              ('help', 8),
#              ('in_reaction_to', 55),
#              ('indicate', 10),
#              ('involuntary', 5),
#              ('involve', 5),
#              ('license', 1),
#              ('limit', 4),
#              ('linger', 2),
#              ('location', 74),
#              ('made_of', 20),
#              ('manner', 114),
#              ('masquerade', 8),
#              ('meets', 6),
#              ('mingled', 18),
#              ('motion', 189),
#              ('necessitate', 3),
#              ('neglect', 2),
#              ('nonagentive_cause', 3),
#              ('occur', 7),
#              ('path_rel', 1447),
#              ('perceive', 15),
#              ('perform', 6),
#              ('physical_form', 21),
#              ('position', 14),
#              ('promote', 3),
#              ('property', 26),
#              ('relate', 2),
#              ('require', 8),
#              ('risk', 3),
#              ('rotational_motion', 4),
#              ('rush', 3),
#              ('satisfy', 2),
#              ('search', 19),
#              ('seem', 4),
#              ('set_member', 4),
#              ('signify', 2),
#              ('sleep', 2),
#              ('social_interaction', 58),
#              ('spend', 7),
#              ('state', 1),
#              ('subjugated', 4),
#              ('successful_in', 12),
#              ('suffocate', 8),
#              ('support', 2),
#              ('suspect', 3),
#              ('take_care_of', 16),
#              ('take_in', 31),
#              ('think', 9),
#              ('time', 5),
#              ('together', 54),
#              ('transfer', 291),
#              ('transfer_info', 1),
#              ('understand', 20),
#              ('urge', 7),
#              ('use', 4),
#              ('utilize', 49),
#              ('value', 12),
#              ('visible', 12),
#              ('void', 1),
#              ('wear', 2),
#              ('weather', 3),
#              ('withdraw', 8),
#              ('work', 10),
#              ('yield', 3)])

# %%
predicates_dict = OrderedDict()
for doc in list(db.verbnet.find({}, {'frames.semantics.predicate':1, 'class_id':1, '_id':0})):
    for frame in doc['frames']:
        for pr in frame['semantics']:
            if pr['predicate'] not in predicates_dict:
                predicates_dict[pr['predicate']] = {'count':1, 'vn_class_members':set([doc['class_id']])}
            else:
                predicates_dict[pr['predicate']]['count']+=1
                predicates_dict[pr['predicate']]['vn_class_members'].add(doc['class_id'])

predicates_dict
# Out:
# OrderedDict([('urge',
#               {'count': 7,
#                'vn_class_members': {'beg-58.2',
#                 'beg-58.2-1',
#                 'beg-58.2-1-1',
#                 'urge-58.1',
#                 'urge-58.1-1',
#                 'urge-58.1-1-1'}}),
#              ('authority_relationship',
#               {'count': 18,
#                'vn_class_members': {'beg-58.2',
#                 'beg-58.2-1',
#                 'beg-58.2-1-1',
#                 'employment-95.3',
#                 'hire-13.5.3',
#                 'order-58.3',
#                 'order-58.3-1',
#                 'subordinate-95.2.1',
#                 'supervision-95.2.2'}}),
#              ('function',
#               {'count': 3,
#                'vn_class_members': {'disfunction-105.2.2',
#                 'function-105.2.1',
#                 'function-105.2.1-1'}}),
#              ('declare',
#               {'count': 23,
#                'vn_class_members': {'declare-29.4',
#                 'declare-29.4-1',
#                 'declare-29.4-1-1',
#                 'declare-29.4-1-1-1',
#                 'declare-29.4-1-1-2',
#                 'declare-29.4-1-1-3',
#                 'declare-29.4-2',
#                 'judgment-33.1',
#                 'judgment-33.1-1',
#                 'judgment-33.1-1-1',
#                 'prosecute-33.2-1'}}),
#              ('social_interaction',
#               {'count': 58,
#                'vn_class_members': {'battle-36.4',
#                 'battle-36.4-1',
#                 'bully-59.5',
#                 'correspond-36.1.1',
#                 'correspond-36.1.1-1',
#                 'correspond-36.1.1-1-1',
#                 'interact-36.6',
#                 'marry-36.2',
#                 'meet-36.3-1',
#                 'meet-36.3-2',
#                 'respond-113',
#                 'trifle-105.3'}}),
#              ('path_rel',
#               {'count': 1447,
#                'vn_class_members': {'accompany-51.7',
#                 'adjust-26.9',
#                 'advise-37.9',
#                 'advise-37.9-1',
#                 'amuse-31.1',
#                 'banish-10.2',
#                 'become-109.1',
#                 'become-109.1-1',
#                 'become-109.1-1-1',
#                 'being_dressed-41.3.3',
#                 'bend-45.2',
#                 'berry-13.7',
#                 'body_internal_states-40.6',
#                 'body_motion-49.2',
#                 'body_motion-49.2-1',
#                 'body_motion-49.2-1-1',
#                 'braid-41.2.2',
#                 'break-45.1',
#                 'breathe-40.1.2',
#                 'bring-11.3',
#                 'bring-11.3-1',
#                 'build-26.1',
#                 'build-26.1-1',
#                 'butter-9.9',
#                 'calibratable_cos-45.6.1',
#                 'calibratable_cos-45.6.1-1',
#                 'carry-11.4',
#                 'carry-11.4-1',
#                 'carry-11.4-1-1',
#                 'caused_calibratable_cos-45.6.2',
#                 'caused_calibratable_cos-45.6.2-1',
#                 'change_bodily_state-40.8.4',
#                 'chase-51.6',
#                 'cheat-10.6.1',
#                 'cheat-10.6.1-1',
#                 'cheat-10.6.1-1-1',
#                 'chit_chat-37.6',
#                 'chit_chat-37.6-1',
#                 'clear-10.3',
#                 'clear-10.3-1',
#                 'coil-9.6',
#                 'coloring-24',
#                 'complain-37.8',
#                 'confess-37.10',
#                 'confine-92',
#                 'confine-92-1',
#                 'consume-66',
#                 'consume-66-1',
#                 'contribute-13.2',
#                 'contribute-13.2-1',
#                 'contribute-13.2-1-1',
#                 'contribute-13.2-2',
#                 'contribute-13.2-2-1',
#                 'convert-26.6.2',
#                 'convert-26.6.2-1',
#                 'convert-26.6.2-1-1',
#                 'cooking-45.3',
#                 'crane-40.3.2',
#                 'create-26.4',
#                 'create-26.4-1-1',
#                 'curtsey-40.3.3',
#                 'cut-21.1',
#                 'debone-10.8',
#                 'deprive-10.6.2',
#                 'disappearance-48.2',
#                 'disappearance-48.2-1',
#                 'dress-41.1.1',
#                 'dressing_well-41.3.2',
#                 'drive-11.5',
#                 'drive-11.5-1',
#                 'entity_specific_cos-45.5',
#                 'equip-13.4.2',
#                 'equip-13.4.2-1',
#                 'escape-51.1',
#                 'escape-51.1-1',
#                 'escape-51.1-1-1',
#                 'escape-51.1-1-2',
#                 'escape-51.1-1-3',
#                 'exchange-13.6.1',
#                 'fill-9.8',
#                 'fill-9.8-1',
#                 'fire-10.10',
#                 'flinch-40.5',
#                 'floss-41.2.1',
#                 'fulfilling-13.4.1',
#                 'fulfilling-13.4.1-1',
#                 'fulfilling-13.4.1-2',
#                 'funnel-9.3',
#                 'funnel-9.3-1',
#                 'funnel-9.3-1-1',
#                 'future_having-13.3',
#                 'future_having-13.3-1',
#                 'get-13.5.1',
#                 'get-13.5.1-1',
#                 'give-13.1',
#                 'give-13.1-1',
#                 'groom-41.1.2',
#                 'grow-26.2.1',
#                 'hit-18.1',
#                 'hurt-40.8.3-1',
#                 'hurt-40.8.3-1-1',
#                 'hurt-40.8.3-2',
#                 'illustrate-25.3',
#                 'image_impression-25.1',
#                 'initiate_communication-37.4.2',
#                 'initiate_communication-37.4.2-1',
#                 'inquire-37.1.2',
#                 'instr_communication-37.4.1',
#                 'interrogate-37.1.3',
#                 'knead-26.5',
#                 'learn-14',
#                 'learn-14-1',
#                 'learn-14-2',
#                 'learn-14-2-1',
#                 'leave-51.2',
#                 'leave-51.2-1',
#                 'lecture-37.11',
#                 'lecture-37.11-1',
#                 'lecture-37.11-1-1',
#                 'lecture-37.11-2',
#                 'manner_speaking-37.3',
#                 'mine-10.9',
#                 'murder-42.1',
#                 'murder-42.1-1',
#                 'nonvehicle-51.4.2',
#                 'nonvehicle-51.4.2-1',
#                 'nonverbal_expression-40.2',
#                 'obtain-13.5.2',
#                 'obtain-13.5.2-1',
#                 'other_cos-45.4',
#                 'other_cos-45.4-1',
#                 'overstate-37.12',
#                 'pain-40.8.1',
#                 'pay-68',
#                 'pay-68-1',
#                 'pelt-17.2',
#                 'pit-10.7',
#                 'pocket-9.10',
#                 'pocket-9.10-1',
#                 'poison-42.2',
#                 'pour-9.5',
#                 'preparing-26.3-1',
#                 'preparing-26.3-2',
#                 'promise-37.13',
#                 'push-12-1',
#                 'push-12-1-1',
#                 'put-9.1',
#                 'put-9.1-1',
#                 'put-9.1-2',
#                 'put_direction-9.4',
#                 'put_spatial-9.2',
#                 'reach-51.8',
#                 'remedy-45.7',
#                 'remedy-45.7-1',
#                 'remove-10.1',
#                 'render-29.90',
#                 'render-29.90-1',
#                 'render-29.90-2',
#                 'resign-10.11',
#                 'resign-10.11-1',
#                 'resign-10.11-2',
#                 'rob-10.6.4',
#                 'roll-51.3.1',
#                 'run-51.3.2',
#                 'run-51.3.2-1',
#                 'run-51.3.2-2',
#                 'run-51.3.2-2-1',
#                 'say-37.7',
#                 'say-37.7-1',
#                 'say-37.7-1-1',
#                 'say-37.7-1-1-1',
#                 'say-37.7-1-2',
#                 'scribble-25.2',
#                 'scribble-25.2-1',
#                 'send-11.1',
#                 'send-11.1-1',
#                 'simple_dressing-41.3.1',
#                 'slide-11.2',
#                 'slide-11.2-1',
#                 'snooze-40.4',
#                 'snooze-40.4-1',
#                 'spank-18.3',
#                 'spray-9.7',
#                 'spray-9.7-1',
#                 'spray-9.7-1-1',
#                 'steal-10.5',
#                 'steal-10.5-1',
#                 'subjugate-42.3',
#                 'substitute-13.6.2',
#                 'substitute-13.6.2-1',
#                 'suffocate-40.7',
#                 'swat-18.2',
#                 'talk-37.5',
#                 'tape-22.4',
#                 'tell-37.2',
#                 'throw-17.1',
#                 'throw-17.1-1',
#                 'tingle-40.8.2',
#                 'transcribe-25.4',
#                 'transfer_mesg-37.1.1',
#                 'transfer_mesg-37.1.1-1',
#                 'transfer_mesg-37.1.1-1-1',
#                 'turn-26.6.1',
#                 'turn-26.6.1-1',
#                 'vehicle-51.4.1',
#                 'vehicle-51.4.1-1',
#                 'vehicle_path-51.4.3',
#                 'void-106',
#                 'waltz-51.5',
#                 'wink-40.3.1',
#                 'wipe_instr-10.4.2',
#                 'wipe_instr-10.4.2-1',
#                 'wipe_manner-10.4.1',
#                 'wipe_manner-10.4.1-1'}}),
#              ('confined',
#               {'count': 2,
#                'vn_class_members': {'confine-92', 'confine-92-1'}}),
#              ('cause',
#               {'count': 713,
#                'vn_class_members': {'accompany-51.7',
#                 'addict-96',
#                 'adjust-26.9',
#                 'advise-37.9',
#                 'advise-37.9-1',
#                 'amalgamate-22.2-1',
#                 'amalgamate-22.2-2',
#                 'amalgamate-22.2-3',
#                 'amalgamate-22.2-3-1',
#                 'amuse-31.1',
#                 'appoint-29.1',
#                 'banish-10.2',
#                 'base-97.1',
#                 'begin-55.1',
#                 'begin-55.1-1',
#                 'begin-55.1-1-1',
#                 'bend-45.2',
#                 'benefit-72.2',
#                 'berry-13.7',
#                 'birth-28.2',
#                 'birth-28.2-1',
#                 'body_motion-49.2',
#                 'body_motion-49.2-1',
#                 'body_motion-49.2-1-1',
#                 'break-45.1',
#                 'bring-11.3',
#                 'bring-11.3-1',
#                 'build-26.1',
#                 'build-26.1-1',
#                 'bully-59.5',
#                 'butter-9.9',
#                 'calve-28.1',
#                 'carry-11.4',
#                 'carry-11.4-1',
#                 'carry-11.4-1-1',
#                 'carve-21.2-1',
#                 'carve-21.2-2',
#                 'caused_calibratable_cos-45.6.2',
#                 'characterize-29.2',
#                 'characterize-29.2-1',
#                 'characterize-29.2-1-1',
#                 'characterize-29.2-1-2',
#                 'chase-51.6',
#                 'cheat-10.6.1',
#                 'cheat-10.6.1-1',
#                 'cheat-10.6.1-1-1',
#                 'chit_chat-37.6',
#                 'chit_chat-37.6-1',
#                 'classify-29.10',
#                 'clear-10.3',
#                 'coil-9.6',
#                 'coloring-24',
#                 'compel-59.1',
#                 'complain-37.8',
#                 'complete-55.2',
#                 'complete-55.2-1',
#                 'concealment-16',
#                 'conduct-111.1',
#                 'confess-37.10',
#                 'confine-92',
#                 'confine-92-1',
#                 'contribute-13.2',
#                 'contribute-13.2-1',
#                 'contribute-13.2-1-1',
#                 'contribute-13.2-2',
#                 'contribute-13.2-2-1',
#                 'convert-26.6.2-1-1',
#                 'cooking-45.3',
#                 'correlate-86.1',
#                 'crane-40.3.2',
#                 'create-26.4',
#                 'create-26.4-1',
#                 'create-26.4-1-1',
#                 'curtsey-40.3.3',
#                 'cut-21.1',
#                 'debone-10.8',
#                 'deprive-10.6.2',
#                 'destroy-44',
#                 'die-42.4',
#                 'die-42.4-1',
#                 'disassemble-23.3',
#                 'drive-11.5',
#                 'drive-11.5-1',
#                 'dub-29.3',
#                 'ensure-99',
#                 'equip-13.4.2',
#                 'equip-13.4.2-1',
#                 'establish-55.5',
#                 'establish-55.5-1',
#                 'exchange-13.6.1',
#                 'feeding-39.7',
#                 'fill-9.8',
#                 'fill-9.8-1',
#                 'fire-10.10',
#                 'fit-54.3',
#                 'focus-87.1',
#                 'focus-87.1-1',
#                 'free-10.6.3',
#                 'free-10.6.3-1',
#                 'free-10.6.3-1-1',
#                 'free-80',
#                 'free-80-1',
#                 'free-80-1-1',
#                 'fulfilling-13.4.1',
#                 'fulfilling-13.4.1-1',
#                 'fulfilling-13.4.1-2',
#                 'funnel-9.3',
#                 'funnel-9.3-1',
#                 'future_having-13.3',
#                 'future_having-13.3-1',
#                 'get-13.5.1',
#                 'get-13.5.1-1',
#                 'give-13.1',
#                 'grow-26.2.1',
#                 'herd-47.5.2',
#                 'hire-13.5.3',
#                 'hit-18.1',
#                 'hit-18.1-1',
#                 'hold-15.1',
#                 'illustrate-25.3',
#                 'image_impression-25.1',
#                 'initiate_communication-37.4.2',
#                 'initiate_communication-37.4.2-1',
#                 'inquire-37.1.2',
#                 'instr_communication-37.4.1',
#                 'interrogate-37.1.3',
#                 'invest-13.5.4',
#                 'invest-13.5.4-1',
#                 'keep-15.2',
#                 'knead-26.5',
#                 'learn-14',
#                 'lecture-37.11',
#                 'lecture-37.11-1',
#                 'lecture-37.11-1-1',
#                 'lecture-37.11-2',
#                 'light_emission-43.1',
#                 'lure-59.3',
#                 'manner_speaking-37.3',
#                 'mine-10.9',
#                 'mix-22.1-1',
#                 'mix-22.1-2',
#                 'modes_of_being_with_motion-47.3',
#                 'murder-42.1',
#                 'murder-42.1-1',
#                 'nonvehicle-51.4.2',
#                 'nonverbal_expression-40.2',
#                 'obtain-13.5.2',
#                 'obtain-13.5.2-1',
#                 'order-58.3',
#                 'order-58.3-1',
#                 'orphan-29.7',
#                 'other_cos-45.4',
#                 'patent-101',
#                 'pay-68',
#                 'pay-68-1',
#                 'pelt-17.2',
#                 'performance-26.7-1',
#                 'pit-10.7',
#                 'pocket-9.10',
#                 'poison-42.2',
#                 'poke-19',
#                 'pour-9.5',
#                 'preparing-26.3-1',
#                 'preparing-26.3-2',
#                 'price-54.4',
#                 'promise-37.13',
#                 'pronounce-29.3.1',
#                 'push-12',
#                 'push-12-1',
#                 'push-12-1-1',
#                 'put-9.1',
#                 'put-9.1-1',
#                 'put-9.1-2',
#                 'put_direction-9.4',
#                 'put_spatial-9.2',
#                 'rear-26.2.2',
#                 'rear-26.2.2-1',
#                 'reflexive_appearance-48.1.2',
#                 'remedy-45.7',
#                 'remove-10.1',
#                 'render-29.90',
#                 'render-29.90-1',
#                 'render-29.90-2',
#                 'resign-10.11',
#                 'resign-10.11-1',
#                 'resign-10.11-2',
#                 'rob-10.6.4',
#                 'roll-51.3.1',
#                 'run-51.3.2-2',
#                 'rush-53.2',
#                 'say-37.7',
#                 'say-37.7-1',
#                 'say-37.7-1-1',
#                 'say-37.7-1-1-1',
#                 'say-37.7-1-2',
#                 'scribble-25.2',
#                 'scribble-25.2-1',
#                 'send-11.1',
#                 'send-11.1-1',
#                 'separate-23.1',
#                 'shake-22.3-1',
#                 'shake-22.3-1-1',
#                 'shake-22.3-2',
#                 'shake-22.3-2-1',
#                 'slide-11.2',
#                 'slide-11.2-1',
#                 'sound_emission-43.2',
#                 'spank-18.3',
#                 'spatial_configuration-47.6-1',
#                 'split-23.2',
#                 'spray-9.7',
#                 'spray-9.7-1',
#                 'steal-10.5',
#                 'steal-10.5-1',
#                 'stimulate-59.4',
#                 'stop-55.4',
#                 'stop-55.4-1-1',
#                 'subjugate-42.3',
#                 'substance_emission-43.4-1-1',
#                 'suffocate-40.7',
#                 'sustain-55.6',
#                 'swat-18.2',
#                 'talk-37.5',
#                 'tape-22.4',
#                 'tell-37.2',
#                 'throw-17.1',
#                 'throw-17.1-1',
#                 'touch-20',
#                 'touch-20-1',
#                 'transcribe-25.4',
#                 'transfer_mesg-37.1.1',
#                 'transfer_mesg-37.1.1-1',
#                 'transfer_mesg-37.1.1-1-1',
#                 'trick-59.2',
#                 'turn-26.6.1',
#                 'turn-26.6.1-1',
#                 'vehicle-51.4.1',
#                 'vehicle_path-51.4.3',
#                 'void-106',
#                 'volunteer-95.4',
#                 'volunteer-95.4-1',
#                 'waltz-51.5',
#                 'wink-40.3.1',
#                 'wipe_instr-10.4.2',
#                 'wipe_instr-10.4.2-1',
#                 'wipe_manner-10.4.1',
#                 'wipe_manner-10.4.1-1'}}),
#              ('motion',
#               {'count': 189,
#                'vn_class_members': {'accompany-51.7',
#                 'assuming_position-50',
#                 'bring-11.3',
#                 'bring-11.3-1',
#                 'butter-9.9',
#                 'carry-11.4',
#                 'carry-11.4-1',
#                 'carry-11.4-1-1',
#                 'chase-51.6',
#                 'drive-11.5',
#                 'drive-11.5-1',
#                 'escape-51.1',
#                 'escape-51.1-1',
#                 'escape-51.1-1-1',
#                 'escape-51.1-1-2',
#                 'escape-51.1-1-3',
#                 'fill-9.8',
#                 'fill-9.8-1',
#                 'funnel-9.3',
#                 'funnel-9.3-1',
#                 'funnel-9.3-1-1',
#                 'leave-51.2',
#                 'leave-51.2-1',
#                 'modes_of_being_with_motion-47.3',
#                 'nonvehicle-51.4.2',
#                 'nonvehicle-51.4.2-1',
#                 'pelt-17.2',
#                 'pocket-9.10',
#                 'pocket-9.10-1',
#                 'pour-9.5',
#                 'push-12-1-1',
#                 'put-9.1',
#                 'put-9.1-1',
#                 'put-9.1-2',
#                 'put_direction-9.4',
#                 'put_spatial-9.2',
#                 'reach-51.8',
#                 'roll-51.3.1',
#                 'run-51.3.2',
#                 'run-51.3.2-1',
#                 'run-51.3.2-2',
#                 'run-51.3.2-2-1',
#                 'send-11.1',
#                 'send-11.1-1',
#                 'slide-11.2',
#                 'slide-11.2-1',
#                 'spray-9.7',
#                 'spray-9.7-1',
#                 'swarm-47.5.1-1',
#                 'throw-17.1',
#                 'throw-17.1-1',
#                 'vehicle-51.4.1',
#                 'vehicle-51.4.1-1',
#                 'vehicle_path-51.4.3',
#                 'waltz-51.5'}}),
#              ('manner',
#               {'count': 114,
#                'vn_class_members': {'battle-36.4',
#                 'battle-36.4-1',
#                 'bully-59.5',
#                 'bump-18.4',
#                 'bump-18.4-1',
#                 'carve-21.2-2',
#                 'cut-21.1',
#                 'cut-21.1-1',
#                 'hit-18.1',
#                 'hit-18.1-1',
#                 'poke-19',
#                 'rob-10.6.4',
#                 'snooze-40.4-1',
#                 'spank-18.3',
#                 'steal-10.5',
#                 'steal-10.5-1',
#                 'swat-18.2',
#                 'trick-59.2'}}),
#              ('contact',
#               {'count': 144,
#                'vn_class_members': {'battle-36.4',
#                 'battle-36.4-1',
#                 'bend-45.2',
#                 'break-45.1',
#                 'bump-18.4',
#                 'bump-18.4-1',
#                 'carve-21.2-1',
#                 'carve-21.2-2',
#                 'contiguous_location-47.8',
#                 'contiguous_location-47.8-1',
#                 'contiguous_location-47.8-2',
#                 'cut-21.1',
#                 'cut-21.1-1',
#                 'hit-18.1',
#                 'hit-18.1-1',
#                 'hold-15.1',
#                 'pelt-17.2',
#                 'poke-19',
#                 'push-12',
#                 'push-12-1',
#                 'push-12-1-1',
#                 'spank-18.3',
#                 'swat-18.2',
#                 'terminus-47.9',
#                 'throw-17.1',
#                 'throw-17.1-1',
#                 'touch-20',
#                 'touch-20-1'}}),
#              ('exist',
#               {'count': 113,
#                'vn_class_members': {'build-26.1',
#                 'build-26.1-1',
#                 'consume-66',
#                 'consume-66-1',
#                 'create-26.4',
#                 'create-26.4-1',
#                 'create-26.4-1-1',
#                 'engender-27.1',
#                 'engender-27.1-1',
#                 'entity_specific_modes_being-47.2',
#                 'exist-47.1',
#                 'exist-47.1-1',
#                 'grow-26.2.1',
#                 'knead-26.5',
#                 'meander-47.7',
#                 'meander-47.7-1',
#                 'modes_of_being_with_motion-47.3',
#                 'performance-26.7-1',
#                 'preparing-26.3-1',
#                 'rear-26.2.2-1',
#                 'result-27.2',
#                 'sound_existence-47.4',
#                 'swarm-47.5.1-1',
#                 'swarm-47.5.1-2',
#                 'swarm-47.5.1-2-1'}}),
#              ('take_care_of',
#               {'count': 16,
#                'vn_class_members': {'braid-41.2.2',
#                 'caring-75.2-1',
#                 'caring-75.2-1-1',
#                 'caring-75.2-2',
#                 'dress-41.1.1',
#                 'dressing_well-41.3.2',
#                 'floss-41.2.1',
#                 'groom-41.1.2',
#                 'rear-26.2.2',
#                 'rear-26.2.2-1'}}),
#              ('act',
#               {'count': 23,
#                'vn_class_members': {'act-114',
#                 'act-114-1',
#                 'act-114-1-1',
#                 'bully-59.5',
#                 'compel-59.1',
#                 'lure-59.3',
#                 'reciprocate-112',
#                 'reciprocate-112-1',
#                 'stimulate-59.4',
#                 'trick-59.2'}}),
#              ('attract', {'count': 3, 'vn_class_members': {'lure-59.3'}}),
#              ('transfer',
#               {'count': 291,
#                'vn_class_members': {'advise-37.9',
#                 'advise-37.9-1',
#                 'berry-13.7',
#                 'cheat-10.6.1',
#                 'cheat-10.6.1-1',
#                 'cheat-10.6.1-1-1',
#                 'chit_chat-37.6',
#                 'chit_chat-37.6-1',
#                 'complain-37.8',
#                 'confess-37.10',
#                 'contribute-13.2',
#                 'contribute-13.2-1',
#                 'contribute-13.2-1-1',
#                 'contribute-13.2-2',
#                 'contribute-13.2-2-1',
#                 'crane-40.3.2',
#                 'curtsey-40.3.3',
#                 'deprive-10.6.2',
#                 'equip-13.4.2',
#                 'equip-13.4.2-1',
#                 'exchange-13.6.1',
#                 'fulfilling-13.4.1',
#                 'fulfilling-13.4.1-1',
#                 'fulfilling-13.4.1-2',
#                 'get-13.5.1',
#                 'get-13.5.1-1',
#                 'give-13.1',
#                 'give-13.1-1',
#                 'initiate_communication-37.4.2',
#                 'initiate_communication-37.4.2-1',
#                 'inquire-37.1.2',
#                 'instr_communication-37.4.1',
#                 'interrogate-37.1.3',
#                 'invest-13.5.4',
#                 'invest-13.5.4-1',
#                 'learn-14',
#                 'learn-14-1',
#                 'learn-14-2',
#                 'learn-14-2-1',
#                 'lecture-37.11',
#                 'lecture-37.11-1',
#                 'lecture-37.11-1-1',
#                 'lecture-37.11-2',
#                 'manner_speaking-37.3',
#                 'nonverbal_expression-40.2',
#                 'obtain-13.5.2',
#                 'obtain-13.5.2-1',
#                 'overstate-37.12',
#                 'pay-68',
#                 'pay-68-1',
#                 'promise-37.13',
#                 'rob-10.6.4',
#                 'say-37.7',
#                 'say-37.7-1',
#                 'say-37.7-1-1',
#                 'say-37.7-1-1-1',
#                 'say-37.7-1-2',
#                 'steal-10.5',
#                 'steal-10.5-1',
#                 'substitute-13.6.2',
#                 'talk-37.5',
#                 'tell-37.2',
#                 'transfer_mesg-37.1.1',
#                 'transfer_mesg-37.1.1-1',
#                 'transfer_mesg-37.1.1-1-1',
#                 'wink-40.3.1'}}),
#              ('equals',
#               {'count': 401,
#                'vn_class_members': {'accompany-51.7',
#                 'addict-96',
#                 'advise-37.9',
#                 'advise-37.9-1',
#                 'berry-13.7',
#                 'breathe-40.1.2',
#                 'bring-11.3',
#                 'carry-11.4',
#                 'chase-51.6',
#                 'cheat-10.6.1',
#                 'cheat-10.6.1-1',
#                 'cheat-10.6.1-1-1',
#                 'chit_chat-37.6',
#                 'chit_chat-37.6-1',
#                 'complain-37.8',
#                 'confess-37.10',
#                 'consume-66',
#                 'consume-66-1',
#                 'contribute-13.2',
#                 'contribute-13.2-1',
#                 'contribute-13.2-1-1',
#                 'contribute-13.2-2',
#                 'contribute-13.2-2-1',
#                 'crane-40.3.2',
#                 'curtsey-40.3.3',
#                 'deprive-10.6.2',
#                 'drive-11.5',
#                 'equip-13.4.2',
#                 'equip-13.4.2-1',
#                 'exchange-13.6.1',
#                 'fulfilling-13.4.1',
#                 'fulfilling-13.4.1-1',
#                 'fulfilling-13.4.1-2',
#                 'future_having-13.3',
#                 'future_having-13.3-1',
#                 'get-13.5.1',
#                 'get-13.5.1-1',
#                 'give-13.1',
#                 'give-13.1-1',
#                 'initiate_communication-37.4.2',
#                 'initiate_communication-37.4.2-1',
#                 'inquire-37.1.2',
#                 'instr_communication-37.4.1',
#                 'interrogate-37.1.3',
#                 'learn-14',
#                 'learn-14-1',
#                 'learn-14-2',
#                 'learn-14-2-1',
#                 'lecture-37.11',
#                 'lecture-37.11-1',
#                 'lecture-37.11-1-1',
#                 'lecture-37.11-2',
#                 'manner_speaking-37.3',
#                 'nonvehicle-51.4.2',
#                 'nonverbal_expression-40.2',
#                 'obtain-13.5.2',
#                 'obtain-13.5.2-1',
#                 'overstate-37.12',
#                 'pay-68',
#                 'pay-68-1',
#                 'poke-19',
#                 'promise-37.13',
#                 'rob-10.6.4',
#                 'run-51.3.2-2',
#                 'say-37.7',
#                 'say-37.7-1',
#                 'say-37.7-1-1',
#                 'say-37.7-1-1-1',
#                 'say-37.7-1-2',
#                 'steal-10.5',
#                 'substitute-13.6.2',
#                 'substitute-13.6.2-1',
#                 'talk-37.5',
#                 'tell-37.2',
#                 'throw-17.1',
#                 'throw-17.1-1',
#                 'transfer_mesg-37.1.1',
#                 'transfer_mesg-37.1.1-1',
#                 'transfer_mesg-37.1.1-1-1',
#                 'vehicle-51.4.1',
#                 'vehicle_path-51.4.3',
#                 'waltz-51.5',
#                 'wink-40.3.1'}}),
#              ('conclude', {'count': 4, 'vn_class_members': {'deduce-97.2'}}),
#              ('exert_force',
#               {'count': 20,
#                'vn_class_members': {'compel-59.1',
#                 'push-12',
#                 'push-12-1',
#                 'push-12-1-1',
#                 'put_direction-9.4',
#                 'throw-17.1',
#                 'throw-17.1-1',
#                 'throw-17.1-1-1'}}),
#              ('search',
#               {'count': 19,
#                'vn_class_members': {'ferret-35.6',
#                 'hunt-35.1',
#                 'investigate-35.4',
#                 'rummage-35.5',
#                 'rummage-35.5-1',
#                 'search-35.2',
#                 'stalk-35.3'}}),
#              ('take_in',
#               {'count': 31,
#                'vn_class_members': {'absorb-39.8',
#                 'chew-39.2-1',
#                 'chew-39.2-2',
#                 'devour-39.4',
#                 'dine-39.5',
#                 'eat-39.1-1',
#                 'eat-39.1-2',
#                 'eat-39.1-3',
#                 'exhale-40.1.3-2',
#                 'feeding-39.7',
#                 'gobble-39.3-1',
#                 'gobble-39.3-2',
#                 'gorge-39.6'}}),
#              ('emotional_state',
#               {'count': 34,
#                'vn_class_members': {'admire-31.2',
#                 'admire-31.2-1',
#                 'amuse-31.1',
#                 'appeal-31.4',
#                 'appeal-31.4-1',
#                 'appeal-31.4-2',
#                 'appeal-31.4-3',
#                 'bully-59.5',
#                 'care-88.1',
#                 'care-88.1-1',
#                 'empathize-88.2',
#                 'marvel-31.3',
#                 'matter-91'}}),
#              ('in_reaction_to',
#               {'count': 55,
#                'vn_class_members': {'admire-31.2',
#                 'admire-31.2-1',
#                 'appeal-31.4',
#                 'appeal-31.4-1',
#                 'appeal-31.4-2',
#                 'appeal-31.4-3',
#                 'body_internal_states-40.6',
#                 'care-88.1',
#                 'care-88.1-1',
#                 'change_bodily_state-40.8.4',
#                 'empathize-88.2',
#                 'encounter-30.5',
#                 'flinch-40.5',
#                 'marvel-31.3',
#                 'matter-91',
#                 'pain-40.8.1',
#                 'peer-30.3',
#                 'reciprocate-112',
#                 'reciprocate-112-1',
#                 'respond-113',
#                 'see-30.1',
#                 'see-30.1-1',
#                 'see-30.1-1-1',
#                 'see-30.1-1-1-1',
#                 'sight-30.2',
#                 'stimulus_subject-30.4',
#                 'tingle-40.8.2'}}),
#              ('conflict',
#               {'count': 23,
#                'vn_class_members': {'battle-36.4',
#                 'battle-36.4-1',
#                 'meet-36.3-2'}}),
#              ('about',
#               {'count': 34,
#                'vn_class_members': {'battle-36.4',
#                 'battle-36.4-1',
#                 'correspond-36.1.1',
#                 'correspond-36.1.1-1',
#                 'correspond-36.1.1-1-1'}}),
#              ('body_motion',
#               {'count': 18,
#                'vn_class_members': {'body_internal_motion-49.1',
#                 'body_motion-49.2',
#                 'body_motion-49.2-1',
#                 'body_motion-49.2-1-1',
#                 'crane-40.3.2',
#                 'wink-40.3.1'}}),
#              ('promote', {'count': 3, 'vn_class_members': {'promote-102'}}),
#              ('free',
#               {'count': 12,
#                'vn_class_members': {'free-10.6.3',
#                 'free-10.6.3-1',
#                 'free-10.6.3-1-1',
#                 'free-80',
#                 'free-80-1',
#                 'free-80-1-1'}}),
#              ('calculate',
#               {'count': 4,
#                'vn_class_members': {'multiply-108',
#                 'multiply-108-1',
#                 'multiply-108-2',
#                 'multiply-108-3'}}),
#              ('designated',
#               {'count': 11,
#                'vn_class_members': {'appoint-29.1',
#                 'dub-29.3',
#                 'orphan-29.7',
#                 'volunteer-95.4',
#                 'volunteer-95.4-1'}}),
#              ('apply_material',
#               {'count': 3, 'vn_class_members': {'coloring-24'}}),
#              ('covered', {'count': 3, 'vn_class_members': {'coloring-24'}}),
#              ('continue',
#               {'count': 9,
#                'vn_class_members': {'continue-55.3',
#                 'hold-15.1',
#                 'sustain-55.6',
#                 'sustain-55.6-1'}}),
#              ('wear',
#               {'count': 2,
#                'vn_class_members': {'being_dressed-41.3.3',
#                 'simple_dressing-41.3.1'}}),
#              ('position',
#               {'count': 14,
#                'vn_class_members': {'assuming_position-50',
#                 'put_spatial-9.2',
#                 'put_spatial-9.2-1',
#                 'spatial_configuration-47.6',
#                 'spatial_configuration-47.6-1'}}),
#              ('location',
#               {'count': 74,
#                'vn_class_members': {'animal_sounds-38',
#                 'appear-48.1.1',
#                 'assuming_position-50',
#                 'concealment-16',
#                 'concealment-16-1',
#                 'eat-39.1-1',
#                 'eat-39.1-2',
#                 'entity_specific_modes_being-47.2',
#                 'illustrate-25.3',
#                 'image_impression-25.1',
#                 'keep-15.2',
#                 'light_emission-43.1',
#                 'linger-53.1',
#                 'lodge-46',
#                 'meander-47.7',
#                 'meander-47.7-1',
#                 'modes_of_being_with_motion-47.3',
#                 'occur-48.3',
#                 'poke-19',
#                 'scribble-25.2',
#                 'scribble-25.2-1',
#                 'smell_emission-43.3',
#                 'sound_emission-43.2',
#                 'sound_existence-47.4',
#                 'spatial_configuration-47.6',
#                 'spatial_configuration-47.6-1',
#                 'substance_emission-43.4-1',
#                 'swarm-47.5.1-1',
#                 'swarm-47.5.1-2',
#                 'swarm-47.5.1-2-1',
#                 'transcribe-25.4',
#                 'weekend-56'}}),
#              ('together',
#               {'count': 54,
#                'vn_class_members': {'amalgamate-22.2',
#                 'amalgamate-22.2-2',
#                 'amalgamate-22.2-2-1',
#                 'amalgamate-22.2-3',
#                 'amalgamate-22.2-3-1',
#                 'amalgamate-22.2-3-1-1',
#                 'amalgamate-22.2-3-2',
#                 'bring-11.3-1',
#                 'cling-22.5',
#                 'disassemble-23.3',
#                 'herd-47.5.2',
#                 'mix-22.1-2',
#                 'mix-22.1-2-1',
#                 'separate-23.1',
#                 'separate-23.1-1',
#                 'separate-23.1-2',
#                 'shake-22.3-2',
#                 'shake-22.3-2-1',
#                 'split-23.2',
#                 'tape-22.4',
#                 'tape-22.4-1'}}),
#              ('understand',
#               {'count': 20,
#                'vn_class_members': {'cognize-85',
#                 'comprehend-87.2',
#                 'comprehend-87.2-1',
#                 'comprehend-87.2-1-1',
#                 'comprehend-87.2-1-1-1'}}),
#              ('property',
#               {'count': 26,
#                'vn_class_members': {'calibratable_cos-45.6.1-1',
#                 'carve-21.2-1',
#                 'carve-21.2-2',
#                 'caused_calibratable_cos-45.6.2-1',
#                 'coil-9.6-1',
#                 'comprehend-87.2',
#                 'comprehend-87.2-1',
#                 'cut-21.1',
#                 'employment-95.3',
#                 'function-105.2.1-1',
#                 'sustain-55.6-1',
#                 'volunteer-95.4-1'}}),
#              ('body_process',
#               {'count': 12,
#                'vn_class_members': {'breathe-40.1.2',
#                 'breathe-40.1.2-1',
#                 'exhale-40.1.3-1',
#                 'exhale-40.1.3-2',
#                 'hiccup-40.1.1',
#                 'snooze-40.4',
#                 'snooze-40.4-1'}}),
#              ('involuntary',
#               {'count': 5,
#                'vn_class_members': {'body_internal_states-40.6',
#                 'change_bodily_state-40.8.4',
#                 'hiccup-40.1.1'}}),
#              ('degradation_material_integrity',
#               {'count': 70,
#                'vn_class_members': {'amalgamate-22.2',
#                 'amalgamate-22.2-1',
#                 'amalgamate-22.2-1-1',
#                 'break-45.1',
#                 'break_down-45.8',
#                 'carve-21.2-1',
#                 'carve-21.2-2',
#                 'cut-21.1',
#                 'cut-21.1-1',
#                 'mix-22.1-1',
#                 'mix-22.1-1-1',
#                 'shake-22.3',
#                 'shake-22.3-1',
#                 'shake-22.3-1-1'}}),
#              ('utilize',
#               {'count': 49,
#                'vn_class_members': {'begin-55.1-1-1',
#                 'bend-45.2',
#                 'break-45.1',
#                 'carve-21.2-1',
#                 'carve-21.2-2',
#                 'cooking-45.3',
#                 'cut-21.1',
#                 'destroy-44',
#                 'distinguish-23.5',
#                 'distinguish-23.5-1',
#                 'establish-55.5-1',
#                 'floss-41.2.1',
#                 'hit-18.1',
#                 'hit-18.1-1',
#                 'murder-42.1',
#                 'murder-42.1-1',
#                 'other_cos-45.4',
#                 'poke-19',
#                 'remedy-45.7',
#                 'spank-18.3',
#                 'subjugate-42.3',
#                 'sustain-55.6',
#                 'swat-18.2',
#                 'touch-20',
#                 'touch-20-1'}}),
#              ('Adv',
#               {'count': 4,
#                'vn_class_members': {'carve-21.2-1',
#                 'carve-21.2-2',
#                 'coil-9.6-1',
#                 'cut-21.1'}}),
#              ('emit',
#               {'count': 38,
#                'vn_class_members': {'animal_sounds-38',
#                 'breathe-40.1.2',
#                 'breathe-40.1.2-1',
#                 'exhale-40.1.3-1',
#                 'light_emission-43.1',
#                 'smell_emission-43.3',
#                 'sound_emission-43.2',
#                 'substance_emission-43.4',
#                 'substance_emission-43.4-1',
#                 'substance_emission-43.4-1-1'}}),
#              ('direction',
#               {'count': 8,
#                'vn_class_members': {'animal_sounds-38',
#                 'bring-11.3-1',
#                 'carry-11.4-1-1',
#                 'put_direction-9.4',
#                 'send-11.1-1',
#                 'slide-11.2-1'}}),
#              ('neglect',
#               {'count': 2,
#                'vn_class_members': {'neglect-75.1', 'neglect-75.1-1'}}),
#              ('attached',
#               {'count': 15, 'vn_class_members': {'tape-22.4', 'tape-22.4-1'}}),
#              ('rotational_motion',
#               {'count': 4, 'vn_class_members': {'coil-9.6', 'coil-9.6-1'}}),
#              ('occur',
#               {'count': 7,
#                'vn_class_members': {'conduct-111.1',
#                 'occur-48.3',
#                 'occur-48.3-1',
#                 'occur-48.3-2'}}),
#              ('benefit',
#               {'count': 28,
#                'vn_class_members': {'benefit-72.2',
#                 'build-26.1',
#                 'build-26.1-1',
#                 'captain-29.8',
#                 'captain-29.8-1',
#                 'captain-29.8-1-1',
#                 'concealment-16',
#                 'concealment-16-1',
#                 'conduct-111.1',
#                 'cost-54.2',
#                 'create-26.4',
#                 'create-26.4-1-1',
#                 'get-13.5.1',
#                 'performance-26.7',
#                 'performance-26.7-1',
#                 'preparing-26.3-1',
#                 'preparing-26.3-2'}}),
#              ('allow',
#               {'count': 9,
#                'vn_class_members': {'allow-64.1',
#                 'allow-64.1-1',
#                 'forbid-64.4',
#                 'forbid-64.4-1',
#                 'let-64.2'}}),
#              ('discomfort',
#               {'count': 10,
#                'vn_class_members': {'pain-40.8.1', 'tingle-40.8.2'}}),
#              ('experience',
#               {'count': 9,
#                'vn_class_members': {'hurt-40.8.3-1',
#                 'hurt-40.8.3-1-1',
#                 'hurt-40.8.3-2',
#                 'pain-40.8.1',
#                 'tingle-40.8.2'}}),
#              ('avoid', {'count': 4, 'vn_class_members': {'avoid-52'}}),
#              ('capacity', {'count': 2, 'vn_class_members': {'fit-54.3'}}),
#              ('assess',
#               {'count': 12,
#                'vn_class_members': {'assessment-34.1',
#                 'estimate-34.2',
#                 'estimate-34.2-1',
#                 'register-54.1-1'}}),
#              ('created_image',
#               {'count': 12,
#                'vn_class_members': {'illustrate-25.3',
#                 'image_impression-25.1',
#                 'scribble-25.2',
#                 'scribble-25.2-1',
#                 'transcribe-25.4'}}),
#              ('sleep',
#               {'count': 2,
#                'vn_class_members': {'snooze-40.4', 'snooze-40.4-1'}}),
#              ('has_possession',
#               {'count': 6,
#                'vn_class_members': {'equip-13.4.2-1-1',
#                 'invest-13.5.4',
#                 'invest-13.5.4-1',
#                 'keep-15.2',
#                 'own-100.1'}}),
#              ('characterize',
#               {'count': 16,
#                'vn_class_members': {'characterize-29.2',
#                 'consider-29.9-1',
#                 'consider-29.9-1-1',
#                 'consider-29.9-1-1-1',
#                 'consider-29.9-2',
#                 'intend-61.2',
#                 'pronounce-29.3.1',
#                 'spend_time-104'}}),
#              ('group', {'count': 3, 'vn_class_members': {'classify-29.10'}}),
#              ('discover',
#               {'count': 20,
#                'vn_class_members': {'discover-84',
#                 'discover-84-1',
#                 'discover-84-1-1'}}),
#              ('masquerade',
#               {'count': 8,
#                'vn_class_members': {'captain-29.8',
#                 'captain-29.8-1',
#                 'captain-29.8-1-1',
#                 'masquerade-29.6',
#                 'masquerade-29.6-1',
#                 'masquerade-29.6-2',
#                 'spend_time-104'}}),
#              ('base', {'count': 4, 'vn_class_members': {'base-97.1'}}),
#              ('change_value',
#               {'count': 17,
#                'vn_class_members': {'calibratable_cos-45.6.1',
#                 'calibratable_cos-45.6.1-1',
#                 'caused_calibratable_cos-45.6.2',
#                 'caused_calibratable_cos-45.6.2-1'}}),
#              ('think',
#               {'count': 9,
#                'vn_class_members': {'focus-87.1', 'focus-87.1-1'}}),
#              ('attempt',
#               {'count': 8,
#                'vn_class_members': {'intend-61.2',
#                 'intend-61.2-1',
#                 'intend-61.2-1-1',
#                 'try-61.1'}}),
#              ('agree',
#               {'count': 6,
#                'vn_class_members': {'settle-36.1.2', 'settle-36.1.2-1'}}),
#              ('seem',
#               {'count': 4,
#                'vn_class_members': {'seem-109',
#                 'seem-109-1',
#                 'seem-109-1-1',
#                 'seem-109-1-1-1'}}),
#              ('body_reflex',
#               {'count': 4,
#                'vn_class_members': {'body_internal_states-40.6',
#                 'change_bodily_state-40.8.4'}}),
#              ('work',
#               {'count': 10,
#                'vn_class_members': {'employment-95.3', 'work-73.2'}}),
#              ('appear',
#               {'count': 8,
#                'vn_class_members': {'appear-48.1.1',
#                 'reflexive_appearance-48.1.2'}}),
#              ('satisfy', {'count': 2, 'vn_class_members': {'satisfy-55.7'}}),
#              ('conspire', {'count': 4, 'vn_class_members': {'conspire-71'}}),
#              ('yield',
#               {'count': 3,
#                'vn_class_members': {'acquiesce-95.1', 'acquiesce-95.1-1'}}),
#              ('filled_with',
#               {'count': 2, 'vn_class_members': {'bulge-47.5.3'}}),
#              ('defend', {'count': 4, 'vn_class_members': {'defend-72.3'}}),
#              ('contain', {'count': 1, 'vn_class_members': {'contain-15.4'}}),
#              ('express',
#               {'count': 5, 'vn_class_members': {'nonverbal_expression-40.2'}}),
#              ('mingled',
#               {'count': 18,
#                'vn_class_members': {'amalgamate-22.2',
#                 'amalgamate-22.2-1',
#                 'amalgamate-22.2-1-1',
#                 'mix-22.1-1',
#                 'mix-22.1-1-1',
#                 'shake-22.3',
#                 'shake-22.3-1',
#                 'shake-22.3-1-1'}}),
#              ('financial_relationship',
#               {'count': 2, 'vn_class_members': {'bill-54.5'}}),
#              ('different',
#               {'count': 6,
#                'vn_class_members': {'differ-23.4',
#                 'distinguish-23.5',
#                 'distinguish-23.5-1'}}),
#              ('nonagentive_cause',
#               {'count': 3,
#                'vn_class_members': {'engender-27.1',
#                 'engender-27.1-1',
#                 'result-27.2'}}),
#              ('depend', {'count': 5, 'vn_class_members': {'rely-70'}}),
#              ('value',
#               {'count': 12,
#                'vn_class_members': {'cost-54.2',
#                 'pay-68',
#                 'pay-68-1',
#                 'price-54.4',
#                 'register-54.1',
#                 'register-54.1-1',
#                 'register-54.1-1-1'}}),
#              ('signify',
#               {'count': 2, 'vn_class_members': {'representation-110.1'}}),
#              ('perceive',
#               {'count': 15,
#                'vn_class_members': {'encounter-30.5',
#                 'peer-30.3',
#                 'see-30.1',
#                 'see-30.1-1',
#                 'see-30.1-1-1',
#                 'see-30.1-1-1-1',
#                 'sight-30.2',
#                 'stimulus_subject-30.4'}}),
#              ('alive',
#               {'count': 14,
#                'vn_class_members': {'birth-28.2',
#                 'birth-28.2-1',
#                 'die-42.4',
#                 'die-42.4-1',
#                 'murder-42.1',
#                 'murder-42.1-1'}}),
#              ('disappear',
#               {'count': 4,
#                'vn_class_members': {'disappearance-48.2',
#                 'disappearance-48.2-1'}}),
#              ('involve',
#               {'count': 5,
#                'vn_class_members': {'exclude-107.3',
#                 'exclude-107.3-1',
#                 'involve-107.1'}}),
#              ('apart',
#               {'count': 16,
#                'vn_class_members': {'disassemble-23.3',
#                 'separate-23.1',
#                 'separate-23.1-1',
#                 'separate-23.1-2',
#                 'split-23.2'}}),
#              ('spend',
#               {'count': 7,
#                'vn_class_members': {'consume-66',
#                 'consume-66-1',
#                 'spend_time-104'}}),
#              ('do',
#               {'count': 12,
#                'vn_class_members': {'consume-66',
#                 'consume-66-1',
#                 'continue-55.3',
#                 'refrain-69',
#                 'spend_time-104'}}),
#              ('subjugated',
#               {'count': 4, 'vn_class_members': {'subjugate-42.3'}}),
#              ('perform',
#               {'count': 6,
#                'vn_class_members': {'performance-26.7',
#                 'rehearse-26.8',
#                 'rehearse-26.8-1'}}),
#              ('necessitate',
#               {'count': 3, 'vn_class_members': {'require-103'}}),
#              ('made_of',
#               {'count': 20,
#                'vn_class_members': {'build-26.1',
#                 'build-26.1-1',
#                 'knead-26.5',
#                 'rear-26.2.2-1'}}),
#              ('state', {'count': 1, 'vn_class_members': {'knead-26.5'}}),
#              ('earn', {'count': 1, 'vn_class_members': {'earn-54.6'}}),
#              ('limit', {'count': 4, 'vn_class_members': {'limit-76'}}),
#              ('void', {'count': 1, 'vn_class_members': {'void-106'}}),
#              ('suffocate',
#               {'count': 8, 'vn_class_members': {'suffocate-40.7'}}),
#              ('license', {'count': 1, 'vn_class_members': {'patent-101'}}),
#              ('financial_interest_in',
#               {'count': 3,
#                'vn_class_members': {'invest-13.5.4', 'invest-13.5.4-1'}}),
#              ('desire',
#               {'count': 22,
#                'vn_class_members': {'addict-96',
#                 'long-32.2',
#                 'long-32.2-1',
#                 'long-32.2-2',
#                 'want-32.1',
#                 'want-32.1-1',
#                 'want-32.1-1-1',
#                 'wish-62'}}),
#              ('apply_heat',
#               {'count': 7, 'vn_class_members': {'cooking-45.3'}}),
#              ('cooked', {'count': 9, 'vn_class_members': {'cooking-45.3'}}),
#              ('destroyed', {'count': 3, 'vn_class_members': {'destroy-44'}}),
#              ('meets',
#               {'count': 6,
#                'vn_class_members': {'throw-17.1', 'throw-17.1-1'}}),
#              ('adopt', {'count': 1, 'vn_class_members': {'adopt-93'}}),
#              ('admit',
#               {'count': 3,
#                'vn_class_members': {'admit-64.3', 'admit-64.3-1'}}),
#              ('physical_form',
#               {'count': 21,
#                'vn_class_members': {'bend-45.2',
#                 'break-45.1',
#                 'carve-21.2-1'}}),
#              ('adjust', {'count': 1, 'vn_class_members': {'adjust-26.9'}}),
#              ('suspect', {'count': 3, 'vn_class_members': {'suspect-81'}}),
#              ('approve',
#               {'count': 9,
#                'vn_class_members': {'accept-77.1',
#                 'reject-77.2',
#                 'reject-77.2-1'}}),
#              ('set_member',
#               {'count': 4,
#                'vn_class_members': {'attend-107.4-1',
#                 'attend-107.4-2',
#                 'comprise-107.2',
#                 'comprise-107.2-1'}}),
#              ('correlate',
#               {'count': 2, 'vn_class_members': {'correlate-86.1'}}),
#              ('weather', {'count': 3, 'vn_class_members': {'weather-57'}}),
#              ('charge',
#               {'count': 5,
#                'vn_class_members': {'prosecute-33.2', 'prosecute-33.2-1'}}),
#              ('linger', {'count': 2, 'vn_class_members': {'linger-53.1'}}),
#              ('time', {'count': 5, 'vn_class_members': {'continue-55.3'}}),
#              ('use', {'count': 4, 'vn_class_members': {'use-105.1'}}),
#              ('begin',
#               {'count': 9,
#                'vn_class_members': {'begin-55.1',
#                 'begin-55.1-1',
#                 'begin-55.1-1-1',
#                 'establish-55.5',
#                 'establish-55.5-1'}}),
#              ('cost',
#               {'count': 12,
#                'vn_class_members': {'build-26.1',
#                 'build-26.1-1',
#                 'get-13.5.1',
#                 'obtain-13.5.2-1'}}),
#              ('harmonize',
#               {'count': 4, 'vn_class_members': {'harmonize-22.6'}}),
#              ('confront', {'count': 2, 'vn_class_members': {'confront-98'}}),
#              ('ensure', {'count': 4, 'vn_class_members': {'ensure-99'}}),
#              ('cooperate',
#               {'count': 13,
#                'vn_class_members': {'cooperate-73.1-1',
#                 'cooperate-73.1-2',
#                 'cooperate-73.1-3',
#                 'work-73.2'}}),
#              ('end',
#               {'count': 7,
#                'vn_class_members': {'complete-55.2',
#                 'complete-55.2-1',
#                 'rush-53.2',
#                 'stop-55.4',
#                 'stop-55.4-1',
#                 'stop-55.4-1-1'}}),
#              ('consider',
#               {'count': 19,
#                'vn_class_members': {'consider-29.9',
#                 'consider-29.9-1',
#                 'consider-29.9-1-1',
#                 'consider-29.9-1-1-1',
#                 'consider-29.9-2'}}),
#              ('give_birth', {'count': 1, 'vn_class_members': {'calve-28.1'}}),
#              ('flinch', {'count': 4, 'vn_class_members': {'flinch-40.5'}}),
#              ('rush', {'count': 3, 'vn_class_members': {'rush-53.2'}}),
#              ('support',
#               {'count': 2,
#                'vn_class_members': {'support-15.3', 'support-15.3-1'}}),
#              ('dedicate', {'count': 2, 'vn_class_members': {'dedicate-79'}}),
#              ('indicate',
#               {'count': 10,
#                'vn_class_members': {'indicate-78',
#                 'indicate-78-1',
#                 'indicate-78-1-1'}}),
#              ('visible',
#               {'count': 12,
#                'vn_class_members': {'concealment-16', 'concealment-16-1'}}),
#              ('cope',
#               {'count': 3,
#                'vn_class_members': {'cope-83', 'cope-83-1', 'cope-83-1-1'}}),
#              ('harmed',
#               {'count': 16,
#                'vn_class_members': {'hurt-40.8.3-1',
#                 'hurt-40.8.3-1-1',
#                 'hurt-40.8.3-2',
#                 'poison-42.2'}}),
#              ('enforce', {'count': 2, 'vn_class_members': {'enforce-63'}}),
#              ('exceed', {'count': 2, 'vn_class_members': {'exceed-90'}}),
#              ('require',
#               {'count': 8,
#                'vn_class_members': {'order-58.3',
#                 'order-58.3-1',
#                 'require-103-1',
#                 'require-103-2'}}),
#              ('risk',
#               {'count': 3, 'vn_class_members': {'risk-94', 'risk-94-1'}}),
#              ('believe',
#               {'count': 4,
#                'vn_class_members': {'conjecture-29.5',
#                 'conjecture-29.5-1',
#                 'conjecture-29.5-2'}}),
#              ('convert',
#               {'count': 7,
#                'vn_class_members': {'convert-26.6.2',
#                 'convert-26.6.2-1',
#                 'convert-26.6.2-1-1'}}),
#              ('describe',
#               {'count': 9,
#                'vn_class_members': {'characterize-29.2-1',
#                 'characterize-29.2-1-1',
#                 'characterize-29.2-1-2'}}),
#              ('help',
#               {'count': 8,
#                'vn_class_members': {'help-72.1-1',
#                 'help-72.1-1-1',
#                 'help-72.1-2'}}),
#              ('withdraw',
#               {'count': 8,
#                'vn_class_members': {'withdraw-82-1',
#                 'withdraw-82-2',
#                 'withdraw-82-3'}}),
#              ('delay', {'count': 1, 'vn_class_members': {'linger-53.1-1'}}),
#              ('successful_in',
#               {'count': 12,
#                'vn_class_members': {'succeed-74-1',
#                 'succeed-74-1-1',
#                 'succeed-74-2',
#                 'succeed-74-3',
#                 'succeed-74-3-1',
#                 'succeed-74-3-1-1'}}),
#              ('relate',
#               {'count': 2,
#                'vn_class_members': {'relate-86.2-1', 'relate-86.2-2'}}),
#              ('transfer_info',
#               {'count': 1, 'vn_class_members': {'say-37.7-1-1-1'}})])

# %%
list(db.verbnet.find({},{'frames.semantics.predicate':1, '_id':0}))
# Out:
# [{'frames': [{'semantics': [{'predicate': 'urge'}]},
#    {'semantics': [{'predicate': 'urge'},
#      {'predicate': 'authority_relationship'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'function'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'declare'}]},
#    {'semantics': [{'predicate': 'declare'}]},
#    {'semantics': [{'predicate': 'declare'}]}]},
#  {'frames': []},
#  {'frames': [{'semantics': [{'predicate': 'social_interaction'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'confined'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'exist'}]},
#    {'semantics': [{'predicate': 'exist'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'take_care_of'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'act'},
#      {'predicate': 'attract'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'act'},
#      {'predicate': 'attract'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'act'},
#      {'predicate': 'attract'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'function'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'take_care_of'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'conclude'}]},
#    {'semantics': [{'predicate': 'conclude'}]},
#    {'semantics': [{'predicate': 'conclude'}]},
#    {'semantics': [{'predicate': 'conclude'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'act'},
#      {'predicate': 'exert_force'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'act'},
#      {'predicate': 'exert_force'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'act'},
#      {'predicate': 'exert_force'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'act'},
#      {'predicate': 'exert_force'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'search'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'take_in'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'emotional_state'},
#      {'predicate': 'in_reaction_to'}]},
#    {'semantics': [{'predicate': 'emotional_state'},
#      {'predicate': 'in_reaction_to'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'contact'},
#      {'predicate': 'manner'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'},
#      {'predicate': 'manner'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'conflict'},
#      {'predicate': 'about'},
#      {'predicate': 'contact'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'body_motion'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'body_motion'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'body_motion'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'body_motion'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'body_motion'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'body_motion'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'body_motion'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'promote'}]},
#    {'semantics': [{'predicate': 'promote'}]},
#    {'semantics': [{'predicate': 'promote'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'free'},
#      {'predicate': 'free'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'free'},
#      {'predicate': 'free'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'calculate'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'designated'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'designated'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'designated'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'designated'}, {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'apply_material'},
#      {'predicate': 'covered'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'apply_material'},
#      {'predicate': 'covered'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'apply_material'},
#      {'predicate': 'covered'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'continue'},
#      {'predicate': 'contact'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'continue'},
#      {'predicate': 'contact'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'wear'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'position'}]},
#    {'semantics': [{'predicate': 'position'}, {'predicate': 'location'}]},
#    {'semantics': [{'predicate': 'position'}, {'predicate': 'location'}]},
#    {'semantics': [{'predicate': 'position'}, {'predicate': 'location'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'authority_relationship'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'together'},
#      {'predicate': 'together'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'together'},
#      {'predicate': 'together'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'together'},
#      {'predicate': 'together'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'understand'},
#      {'predicate': 'property'}]},
#    {'semantics': [{'predicate': 'understand'}, {'predicate': 'property'}]},
#    {'semantics': [{'predicate': 'understand'}, {'predicate': 'property'}]},
#    {'semantics': [{'predicate': 'understand'}, {'predicate': 'property'}]},
#    {'semantics': [{'predicate': 'understand'}, {'predicate': 'property'}]},
#    {'semantics': [{'predicate': 'understand'}, {'predicate': 'property'}]},
#    {'semantics': [{'predicate': 'understand'}, {'predicate': 'property'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'social_interaction'}]},
#    {'semantics': [{'predicate': 'social_interaction'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'body_process'},
#      {'predicate': 'involuntary'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'degradation_material_integrity'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'degradation_material_integrity'}]},
#    {'semantics': [{'predicate': 'contact'},
#      {'predicate': 'degradation_material_integrity'}]},
#    {'semantics': [{'predicate': 'property'}, {'predicate': 'Adv'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'utilize'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'designated'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'cause'}, {'predicate': 'designated'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'emit'}]},
#    {'semantics': [{'predicate': 'emit'}, {'predicate': 'direction'}]},
#    {'semantics': [{'predicate': 'emit'}]},
#    {'semantics': [{'predicate': 'emit'}, {'predicate': 'location'}]},
#    {'semantics': [{'predicate': 'emit'}, {'predicate': 'location'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'neglect'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'attached'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'together'},
#      {'predicate': 'attached'},
#      {'predicate': 'attached'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'together'},
#      {'predicate': 'attached'},
#      {'predicate': 'attached'}]},
#    {'semantics': [{'predicate': 'together'},
#      {'predicate': 'attached'},
#      {'predicate': 'attached'}]},
#    {'semantics': [{'predicate': 'together'},
#      {'predicate': 'attached'},
#      {'predicate': 'attached'}]},
#    {'semantics': [{'predicate': 'together'},
#      {'predicate': 'attached'},
#      {'predicate': 'attached'}]},
#    {'semantics': [{'predicate': 'together'},
#      {'predicate': 'attached'},
#      {'predicate': 'attached'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'attached'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'position'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'position'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'social_interaction'},
#      {'predicate': 'emotional_state'},
#      {'predicate': 'manner'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'social_interaction'},
#      {'predicate': 'act'},
#      {'predicate': 'manner'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'social_interaction'},
#      {'predicate': 'act'},
#      {'predicate': 'manner'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'rotational_motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'rotational_motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'rotational_motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'occur'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'occur'},
#      {'predicate': 'cause'},
#      {'predicate': 'benefit'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'allow'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'discomfort'},
#      {'predicate': 'discomfort'},
#      {'predicate': 'experience'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'discomfort'},
#      {'predicate': 'discomfort'},
#      {'predicate': 'experience'},
#      {'predicate': 'in_reaction_to'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'contact'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'authority_relationship'},
#      {'predicate': 'authority_relationship'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'authority_relationship'},
#      {'predicate': 'authority_relationship'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'authority_relationship'},
#      {'predicate': 'authority_relationship'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'exist'},
#      {'predicate': 'exist'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'exist'},
#      {'predicate': 'exist'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'exist'},
#      {'predicate': 'exist'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'exist'},
#      {'predicate': 'exist'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'avoid'}]},
#    {'semantics': [{'predicate': 'avoid'}]},
#    {'semantics': [{'predicate': 'avoid'}]},
#    {'semantics': [{'predicate': 'avoid'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'capacity'}]},
#    {'semantics': [{'predicate': 'capacity'}, {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'take_in'}]},
#    {'semantics': [{'predicate': 'take_in'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'assess'}]},
#    {'semantics': [{'predicate': 'assess'}]},
#    {'semantics': [{'predicate': 'assess'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'created_image'},
#      {'predicate': 'location'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'created_image'},
#      {'predicate': 'location'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'search'}]},
#    {'semantics': [{'predicate': 'search'}]},
#    {'semantics': [{'predicate': 'search'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'body_process'},
#      {'predicate': 'sleep'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'has_possession'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'location'},
#      {'predicate': 'equals'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'cause'}, {'predicate': 'manner'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'manner'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'characterize'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'characterize'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'characterize'}, {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'group'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'group'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'group'}, {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'discover'}]},
#    {'semantics': [{'predicate': 'discover'}]},
#    {'semantics': [{'predicate': 'discover'}]},
#    {'semantics': [{'predicate': 'discover'}]},
#    {'semantics': [{'predicate': 'discover'}]},
#    {'semantics': [{'predicate': 'discover'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'masquerade'},
#      {'predicate': 'benefit'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'}, {'predicate': 'base'}]},
#    {'semantics': [{'predicate': 'cause'}, {'predicate': 'base'}]},
#    {'semantics': [{'predicate': 'cause'}, {'predicate': 'base'}]},
#    {'semantics': [{'predicate': 'cause'}, {'predicate': 'base'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'emotional_state'},
#      {'predicate': 'in_reaction_to'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'change_value'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'change_value'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'change_value'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'think'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'think'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'think'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'think'}, {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'authority_relationship'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'attempt'}]},
#    {'semantics': [{'predicate': 'attempt'}, {'predicate': 'characterize'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'},
#      {'predicate': 'manner'},
#      {'predicate': 'contact'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'agree'}]},
#    {'semantics': [{'predicate': 'agree'}]},
#    {'semantics': [{'predicate': 'agree'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'location'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'equals'},
#      {'predicate': 'equals'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'position'},
#      {'predicate': 'motion'},
#      {'predicate': 'position'}]},
#    {'semantics': [{'predicate': 'position'},
#      {'predicate': 'motion'},
#      {'predicate': 'position'},
#      {'predicate': 'location'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'seem'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'body_reflex'},
#      {'predicate': 'involuntary'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'body_reflex'},
#      {'predicate': 'involuntary'},
#      {'predicate': 'in_reaction_to'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'search'}]},
#    {'semantics': [{'predicate': 'search'}]},
#    {'semantics': [{'predicate': 'search'}]},
#    {'semantics': [{'predicate': 'search'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'masquerade'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'work'},
#      {'predicate': 'authority_relationship'}]},
#    {'semantics': [{'predicate': 'work'},
#      {'predicate': 'authority_relationship'}]},
#    {'semantics': [{'predicate': 'work'},
#      {'predicate': 'authority_relationship'}]},
#    {'semantics': [{'predicate': 'work'},
#      {'predicate': 'authority_relationship'}]},
#    {'semantics': [{'predicate': 'work'},
#      {'predicate': 'authority_relationship'},
#      {'predicate': 'property'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'appear'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'appear'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'appear'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'contact'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'satisfy'}]},
#    {'semantics': [{'predicate': 'satisfy'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'conspire'}]},
#    {'semantics': [{'predicate': 'conspire'}]},
#    {'semantics': [{'predicate': 'conspire'}]},
#    {'semantics': [{'predicate': 'conspire'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'take_in'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'motion'},
#      {'predicate': 'equals'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'motion'},
#      {'predicate': 'equals'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'allow'}]},
#    {'semantics': [{'predicate': 'allow'}]},
#    {'semantics': [{'predicate': 'allow'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': []},
#  {'frames': [{'semantics': [{'predicate': 'yield'}]},
#    {'semantics': [{'predicate': 'yield'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'act'},
#      {'predicate': 'manner'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'act'},
#      {'predicate': 'manner'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'act'},
#      {'predicate': 'manner'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'filled_with'}]},
#    {'semantics': [{'predicate': 'filled_with'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'assess'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'defend'}]},
#    {'semantics': [{'predicate': 'defend'}]},
#    {'semantics': [{'predicate': 'defend'}]},
#    {'semantics': [{'predicate': 'defend'}]}]},
#  {'frames': []},
#  {'frames': [{'semantics': [{'predicate': 'contain'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'express'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'express'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'express'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'express'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'},
#      {'predicate': 'express'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'emit'}]},
#    {'semantics': [{'predicate': 'emit'}, {'predicate': 'location'}]},
#    {'semantics': [{'predicate': 'emit'}, {'predicate': 'location'}]},
#    {'semantics': [{'predicate': 'emit'}, {'predicate': 'location'}]},
#    {'semantics': [{'predicate': 'emit'}, {'predicate': 'location'}]},
#    {'semantics': [{'predicate': 'emit'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'emit'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'degradation_material_integrity'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'mingled'}]},
#    {'semantics': [{'predicate': 'together'}]}]},
#  {'frames': []},
#  {'frames': [{'semantics': [{'predicate': 'exist'}]},
#    {'semantics': [{'predicate': 'exist'}, {'predicate': 'location'}]},
#    {'semantics': [{'predicate': 'exist'}]},
#    {'semantics': [{'predicate': 'exist'}, {'predicate': 'location'}]},
#    {'semantics': [{'predicate': 'exist'}, {'predicate': 'location'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'together'}]},
#    {'semantics': [{'predicate': 'together'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'financial_relationship'}]},
#    {'semantics': [{'predicate': 'financial_relationship'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'different'}]},
#    {'semantics': [{'predicate': 'different'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'exist'},
#      {'predicate': 'exist'},
#      {'predicate': 'nonagentive_cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'depend'}]},
#    {'semantics': [{'predicate': 'depend'}]},
#    {'semantics': [{'predicate': 'depend'}]},
#    {'semantics': [{'predicate': 'depend'}]},
#    {'semantics': [{'predicate': 'depend'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'contact'},
#      {'predicate': 'exert_force'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'}, {'predicate': 'act'}]},
#    {'semantics': [{'predicate': 'cause'}, {'predicate': 'act'}]},
#    {'semantics': [{'predicate': 'cause'}, {'predicate': 'act'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'value'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'signify'}]},
#    {'semantics': [{'predicate': 'signify'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'emotional_state'}]},
#    {'semantics': [{'predicate': 'emotional_state'}]},
#    {'semantics': [{'predicate': 'cause'}, {'predicate': 'emotional_state'}]},
# ...
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'},
#      {'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'motion'},
#      {'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'occur'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'occur'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'take_in'}]},
#    {'semantics': [{'predicate': 'take_in'}]},
#    {'semantics': [{'predicate': 'take_in'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'take_in'}]},
#    {'semantics': [{'predicate': 'take_in'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'require'},
#      {'predicate': 'authority_relationship'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'risk'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'believe'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'believe'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'act'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'convert'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'alive'},
#      {'predicate': 'alive'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'urge'},
#      {'predicate': 'authority_relationship'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'declare'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'free'},
#      {'predicate': 'free'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'free'},
#      {'predicate': 'free'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'understand'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'describe'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'describe'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'describe'}, {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'describe'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'describe'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'describe'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'describe'}, {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'discover'}]},
#    {'semantics': [{'predicate': 'discover'}]},
#    {'semantics': [{'predicate': 'discover'}]},
#    {'semantics': [{'predicate': 'discover'}]},
#    {'semantics': [{'predicate': 'discover'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'masquerade'},
#      {'predicate': 'benefit'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'attempt'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'cause'},
#      {'predicate': 'equals'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'seem'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'help'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'degradation_material_integrity'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'mingled'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'together'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'together'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'together'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'contact'},
#      {'predicate': 'exert_force'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'motion'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'contact'},
#      {'predicate': 'exert_force'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'motion'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'value'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'take_care_of'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'body_motion'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'degradation_material_integrity'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'mingled'}]},
#    {'semantics': [{'predicate': 'cause'},
#      {'predicate': 'degradation_material_integrity'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'together'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'direction'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'urge'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'harmed'},
#      {'predicate': 'harmed'},
#      {'predicate': 'experience'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'exert_force'}]},
#    {'semantics': [{'predicate': 'exert_force'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'desire'}]},
#    {'semantics': [{'predicate': 'desire'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'has_possession'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'exist'},
#      {'predicate': 'location'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'emit'}, {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'successful_in'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'successful_in'}]},
#    {'semantics': [{'predicate': 'successful_in'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cause'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'characterize'},
#      {'predicate': 'consider'}]},
#    {'semantics': [{'predicate': 'consider'}]},
#    {'semantics': [{'predicate': 'consider'}]},
#    {'semantics': [{'predicate': 'consider'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'degradation_material_integrity'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'mingled'}]},
#    {'semantics': [{'predicate': 'degradation_material_integrity'},
#      {'predicate': 'degradation_material_integrity'},
#      {'predicate': 'mingled'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'together'}]},
#    {'semantics': [{'predicate': 'together'}]},
#    {'semantics': [{'predicate': 'together'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'end'}, {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'declare'}]},
#    {'semantics': [{'predicate': 'declare'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'about'}]},
#    {'semantics': [{'predicate': 'social_interaction'},
#      {'predicate': 'about'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'perceive'},
#      {'predicate': 'in_reaction_to'}]},
#    {'semantics': [{'predicate': 'perceive'}, {'predicate': 'in_reaction_to'}]},
#    {'semantics': [{'predicate': 'perceive'},
#      {'predicate': 'in_reaction_to'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'indicate'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'cope'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'begin'}]},
#    {'semantics': [{'predicate': 'begin'}, {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'begin'}, {'predicate': 'utilize'}]},
#    {'semantics': [{'predicate': 'begin'},
#      {'predicate': 'utilize'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'begin'}, {'predicate': 'utilize'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'exist'},
#      {'predicate': 'exist'},
#      {'predicate': 'cause'},
#      {'predicate': 'benefit'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'motion'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'path_rel'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'act'}]},
#    {'semantics': [{'predicate': 'act'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'convert'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'convert'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'convert'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'convert'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'understand'}]},
#    {'semantics': [{'predicate': 'understand'}]},
#    {'semantics': [{'predicate': 'understand'}]},
#    {'semantics': [{'predicate': 'understand'}]},
#    {'semantics': [{'predicate': 'understand'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'seem'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'together'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'transfer_info'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]},
#    {'semantics': [{'predicate': 'path_rel'},
#      {'predicate': 'path_rel'},
#      {'predicate': 'transfer'},
#      {'predicate': 'equals'},
#      {'predicate': 'cause'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'successful_in'}]},
#    {'semantics': [{'predicate': 'successful_in'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'consider'}]},
#    {'semantics': [{'predicate': 'characterize'}, {'predicate': 'consider'}]},
#    {'semantics': [{'predicate': 'characterize'}, {'predicate': 'consider'}]},
#    {'semantics': [{'predicate': 'characterize'}, {'predicate': 'consider'}]},
#    {'semantics': [{'predicate': 'consider'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'declare'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'declare'}]},
#    {'semantics': [{'predicate': 'declare'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'declare'}]}]},
#  {'frames': [{'semantics': [{'predicate': 'perceive'},
#      {'predicate': 'in_reaction_to'}]}]}]

# %%
predicate_count_dict = OrderedDict()
for doc in list(db.verbnet.find({}, {'frames.description':1, '_id':0})):
    for frame in doc['frames']:
        print(frame['description']['primary'])
        #         primary = frame['primary']
# Out:
# NP V NP S_INF
# NP V S_INF
# NP V
# NP V NP
# NP V NP PP.attribute
# NP V NP.attribute
# NP V PP.theme
# NP V NP
# NP.theme V
# NP V PP.location
# NP V NP.theme
# NP V NP PP.location
# NP V ADJ
# NP V PP.result
# NP V NP ADJ
# NP V NP PP.result
# NP V PP.location
# NP V NP ADJP
# NP V ADJP NP
# NP V NP
# NP V
# NP V PP.location
# NP V NP
# NP V NP
# NP V NP S_ING
# NP V NP PP.result
# NP V
# NP V NP
# NP V
# NP V PP.co-agent
# NP V PP.co-agent
# NP V PP.co-agent PP.topic
# NP V PP.co-agent PP.topic
# NP V
# NP V together
# NP V PP.topic PP.co-agent
# NP V PP.topic PP.co-agent
# NP V PP.topic
# NP V NP
# NP V NP PP.source
# NP V that S PP.theme
# NP V that S
# NP V NP
# NP V NP S_ING
# NP V NP PP.result
# NP V NP S_INF
# NP V NP PP.source
# NP V NP
# NP V
# NP V PP.stimulus
# NP V PP.co-agent
# NP V
# NP V PP.co-agent PP.theme whether S
# NP V PP.co-agent PP.theme what S
# NP V PP.co-agent PP.theme what S_INF
# NP V PP.co-agent PP.theme whether S_INF
# NP V PP.co-agent PP.theme
# NP V PP.topic NP S_ING
# NP V PP.theme whether S
# NP V PP.theme what S
# NP V PP.theme whether S_INF
# NP V PP.theme what S_INF
# NP V PP.theme
# NP V NP
# NP V NP PP.theme
# NP V
# NP V PP.recipient
# NP V NP
# NP V PP.theme
# NP V NP
# NP V NP
# NP V S_ING
# NP V S_ING
# NP V NP PP.theme
# NP V NP PP.theme
# NP V NP
# NP V NP NP
# NP V NP PP.result
# NP V NP to be NP
# NP V NP
# NP V NP
# NP V NP ADJP
# NP V NP PP.result
# NP V NP
# NP V NP
# NP V NP
# NP V
# NP V PP.location
# There V PP NP
# PP.location V NP
# NP V PP.co-agent
# NP V
# NP V NP.theme
# NP V NP together
# NP V how S
# NP V NP
# NP V NP PP.attribute
# NP V S_ING
# NP V why S
# NP V what S
# NP V that S
# NP V
# NP V NP
# NP V
# NP V NP
# NP V NP PP.instrument
# NP V PP
# NP V PP
# NP V PP PP
# NP V ADVP-Middle
# NP.instrument V NP
# NP.instrument V ADVP
# NP V NP ADJP
# NP V NP ADJP PP.instrument
# NP V NP PP.result
# NP V NP PP.result PP.instrument
# NP V NP ADJP
# NP V NP PP.result
# NP V NP PP.source
# NP V NP PP.source PP.instrument
# NP V NP.location
# NP V NP PP.location
# NP V NP.location PP.theme
# NP V NP NP
# NP V NP
# NP V
# NP V PP.recipient
# NP V NP.theme
# NP V PP.location
# NP.location V PP.agent
# NP.theme V
# NP V PP.trajectory PP.goal
# NP V NP PP.trajectory
# NP V NP ADJP
# NP V NP PP.goal
# NP V NP
# NP V NP
# NP V NP PP.co-patient
# NP V NP together
# NP V ADV-Middle PP
# NP V ADV-Middle
# NP V ADV-Middle together
# NP V together ADV-Middle
# NP V NP ADJP
# NP V NP PP.destination
# NP V NP ADVP
# NP V NP
# NP V NP S_ING
# NP V NP PP.result
# NP V NP PP.location
# NP V PP.location
# NP V ADV-Middle PP.location
# NP V NP
# NP V NP PP
# NP V NP PP.theme
# NP V
# NP V PP.stimulus
# NP.agent V
# NP V PP.location
# NP V NP PP.location
# NP V NP
# NP V NP.location
# NP V NP ADJ
# NP V NP PP.recipient
# NP V NP-Dative NP
# NP V NP
# NP V PP.recipient
# NP V NP
# NP V NP PP.attribute
# NP V NP to be NP
# NP.material V PP.product
# NP.product V PP.material
# NP V NP.product PP.material
# NP V NP.material PP.product
# NP V NP.recipient
# NP V NP.recipient PP.topic
# NP V NP.recipient S
# NP V NP.location
# NP V NP.theme
# NP V S_ING
# NP V S_ING
# NP V NP
# NP.location V NP
# NP V NP PP.location
# NP V
# NP V PP.patient
# NP V NP
# NP V NP PP.attribute
# NP V NP.attribute
# NP V NP
# NP V NP PP.destination
# NP V NP PP.theme
# NP V NP PP.location
# NP V NP
# NP V
# NP V NP
# NP V NP
# NP V NP PP.patient
# NP V NP PP.instrument
# NP V PP
# NP V PP PP
# NP.instrument V NP
# NP V NP S_ING
# NP V NP to be ADJ
# NP V NP PP.attribute
# NP V NP
# NP V NP PP.goal
# NP V NP PP.location
# NP V NP
# NP V NP.recipient
# NP V NP PP.recipient
# NP V NP-Dative NP
# NP V NP.recipient S-Quote
# NP V PP.recipient S-Quote
# NP V NP PP.topic
# NP V that S
# NP V when S_INF
# NP V S_INF
# NP V NP.recipient that S
# NP V NP.recipient when S_INF
# NP V NP.recipient S_INF
# NP V PP.recipient that S
# NP V PP.recipient when S_INF
# NP V PP.recipient S_INF
# NP V for NP S_INF
# NP V how S
# NP V how S_INF
# NP V NP
# NP V that S
# NP V what S
# NP V what S_INF
# NP V PP.beneficiary
# NP V NP PP.source
# NP V NP PP.source whether S
# NP V NP PP.source S_ING
# NP V NP PP.source S
# NP V PP.experiencer
# NP.attribute V
# NP.patient V PP.attribute
# NP V
# NP V PP.topic
# NP V PP.theme S_ING
# NP V PP.topic what S
# NP V PP.topic what S_INF
# NP V NP
# NP V PP.agent
# NP V S_INF
# NP V NP PP.attribute
# NP V NP PP.recipient
# NP V NP.theme (PP)
# NP V PP.recipient NP
# NP V NP
# NP V NP PP.instrument
# NP V PP
# NP V PP PP
# NP V NP ADJP
# NP V NP ADJP PP.instrument
# NP V NP PP.result
# NP V NP PP.result PP.instrument
# NP V NP PP.location
# NP V
# NP V PP.goal what S_INF
# NP V PP.co-agent PP.goal
# NP V PP.location
# NP V NP PP.co-theme
# NP V NP
# NP V PP.theme
# NP V NP PP.co-agent
# NP V NP
# NP V
# NP V PP.location
# NP V ADJ
# NP V
# NP V PP.stimulus
# NP V NP PP.theme
# NP V PP.theme NP.location
# NP V PP.location PP.theme
# NP V PP.location
# NP V NP
# NP V NP PP.destination
# NP V PP.destination NP
# NP V NP PP.initial_location
# NP V NP PP.initial_location PP.destination
# NP V NP ADVP
# NP V PP.attribute
# NP V NP PP.destination
# NP V NP ADVP
# NP V
# NP V PP.recipient
# NP V that S
# NP V PP.recipient that S
# NP V PP.topic
# NP V PP.topic PP.recipient
# NP V S-Quote
# NP V PP.recipient S-Quote
# NP V PP.recipient PP.topic
# NP.patient V
# NP V
# NP V PP
# NP V PP
# NP V PP PP
# NP V PP PP
# NP V NP
# NP V NP PP.recipient
# NP V NP
# NP V NP
# NP V NP PP.destination
# NP V NP.destination PP.theme
# NP V NP.theme
# NP V NP.destination
# NP V NP
# NP V NP PP
# NP V
# NP V PP.co-agent
# NP V PP.beneficiary
# NP V S_INF
# NP V PP.patient
# NP V NP
# NP V NP PP.destination
# NP V NP
# NP V S_ING
# NP V S_ING
# NP V NP.recipient
# NP V PP.co-agent
# NP V PP.theme
# NP V NP
# NP V NP S_ING
# NP V NP PP.result
# NP V PP.theme
# NP V
# NP V NP PP.value
# NP V NP
# NP V NP PP.theme
# NP V S_ING
# NP V S_ING
# NP V NP
# NP V
# NP V NP
# NP V NP
# NP V PP.theme
# NP V PP.recipient
# NP V NP PP.goal
# NP V NP.theme (PP)
# NP V NP-Dative NP
# NP V NP PP.goal
# NP V NP PP PP
# NP V
# NP V PP.location
# NP.location V PP.theme
# PP.location V NP
# There V NP PP
# NP V NP.theme
# NP V NP
# NP V ADVP-Middle PP
# NP V ADVP-Middle
# NP V
# NP V PP.location
# There V NP
# NP.location V NP
# NP.location V PP.theme
# NP V PP.co-theme
# NP V together
# NP V NP.recipient
# NP V NP NP.asset
# NP V PP.co-theme
# NP V
# NP V PP
# NP V PP.theme S_ING
# NP V PP.theme NP S_ING
# NP V PP.theme S_INF
# NP V PP.theme S_ING
# NP V PP.theme
# NP.theme V
# NP.theme V PP.location
# NP V NP PP.location
# NP V NP
# NP V NP ADJ
# NP V NP PP.result
# NP V NP
# NP V NP
# NP V NP S_ING
# NP V NP PP.result
# NP V PP.value
# NP V NP
# NP V NP PP.manner
# NP V NP
# NP V ADV-Middle
# NP V NP-PRO-ARB
# NP.cause V NP
# NP V NP ADJ
# NP V NP
# NP V NP
# NP V NP PP.instrument
# NP V NP ADJP
# NP V NP PP.result
# NP V NP PP.result PP.instrument
# NP V NP PP.location
# NP V NP PP PP.instrument
# NP V NP
# NP V NP.patient PP.material PP.result
# NP.patient V PP.material PP.result
# NP V NP.patient PP.result
# NP.patient V PP.result
# NP V
# NP V NP
# NP V
# NP V PP.initial_location
# NP V PP.destination
# NP V PP.initial_location PP.destination
# NP.agent V NP
# NP V NP PP.initial_location
# NP V NP PP.destination
# NP V NP PP.initial_location PP.destination
# NP V NP.destination
# NP V NP PP.theme
# NP V
# NP V PP.co-theme
# NP V NP.location
# NP V NP PP.co-theme
# NP V NP
# NP V NP PP.source
# NP V NP PP.attribute
# NP V
# NP V
# NP V PP.location
# There V NP PP
# PP.location V NP
# NP V ADV
# NP V NP PP.goal
# NP V NP
# NP V
# NP V NP
# NP V NP
# NP V NP PP.theme
# NP V PP.theme PP.location
# NP V PP.location PP.theme
# NP V NP PP.location
# NP V NP
# NP V
# NP V NP S
# NP V NP PP.co-patient
# NP V NP apart
# NP V PP.co-patient
# NP V apart
# NP V PP ADV-Middle
# NP V ADV-Middle
# NP V NP
# NP V NP PP.attribute
# NP V NP PP.attribute
# NP V NP
# NP V NP PP.instrument
# NP V NP.patient
# NP V NP PP.instrument
# NP.patient V
# NP V ADV-Middle
# NP.instrument V NP
# NP V NP
# NP V NP
# NP V S_ING
# NP V
# NP V PP.location
# There V NP
# PP.location V NP
# NP V NP.theme
# NP V NP
# NP V NP
# NP V for NP S_INF
# NP V that S
# NP V NP ADV
# NP V ADV NP
# NP V ADV-Middle
# NP V together ADV-Middle
# NP.material V PP.product
# NP V NP.material PP.product
# NP V NP.material
# NP V NP
# NP V
# NP V NP PP.instrument
# NP V PP.instrument
# NP V NP
# NP V NP
# NP V NP PP.attribute
# NP V NP.stimulus
# NP V that S
# NP V S_ING
# NP V NP S_ING
# NP V
# NP V
# NP V PP.recipient
# NP V NP
# NP V NP PP.recipient
# NP V NP
# NP V NP PP.destination
# NP V NP PP.initial_location
# NP V NP PP.initial_location PP.destination
# NP V NP PP.destination PP.initial_location
# NP V NP
# NP V NP PP.source
# NP V NP PP.destination
# NP V NP
# NP V NP PP.source
# NP V NP PP.beneficiary
# NP V NP PP.source PP.beneficiary
# NP V NP
# NP V NP PP.destination
# NP V ADJ
# NP V ADJ PP.experiencer
# NP V PP.attribute
# NP V NP.theme PP.destination
# NP V NP.destination PP.theme
# NP V NP.destination
# NP V NP.theme
# NP V
# NP V NP
# NP V NP
# NP V NP S_ING
# NP V NP PP.goal
# NP V NP S_INF
# NP V
# NP V PP.theme S_ING
# NP V PP.theme S
# NP V NP
# NP V NP PP.attribute
# NP V NP PP.topic
# NP V S_INF
# NP V PP
# NP V NP PP
# NP V NP
# NP V NP S_ING
# NP V NP PP.co-patient
# NP V NP
# NP V
# NP V ADVP-Middle PP
# NP V ADVP-Middle
# NP V NP
# NP V NP PP.location
# NP V NP
# NP V NP
# NP V NP PP.location
# NP V PP.theme
# NP V NP NP
# NP V NP that S
# NP V S_ING
# NP V PP.recipient that S
# NP V that S
# NP V
# NP V NP PP.theme
# NP V NP
# NP V NP.patient
# NP V NP PP.instrument
# NP V NP
# NP V NP PP.source
# NP V NP
# NP V NP PP.recipient
# NP V NP PP.recipient PP.theme
# NP V PP.location
# NP V ADV
# NP V NP.theme
# NP.theme V
# NP V PP.result
# NP V NP PP.result
# NP V NP
# NP V NP
# NP V NP PP.destination
# NP V NP PP.initial_location
# NP V NP PP.initial_location PP.destination
# NP V NP PP.destination PP.initial_location
# NP V PP
# NP V NP.initial_location
# NP V S_INF
# Passive
# NP V NP.patient
# NP V NP PP.instrument
# NP.patient V
# NP V ADV-Middle
# NP.instrument V NP
# NP V NP PP.result
# NP V NP PP.result PP.instrument
# NP V PP.result
# NP V PP.result PP.instrument
# NP V NP
# NP V NP PP.source
# NP V NP PP.beneficiary
# NP V NP PP.source PP.beneficiary
# NP V PP.location
# PP.location V NP
# There V PP NP
# There V NP PP
# NP V NP.value
# NP V NP NP
# NP V NP
# NP V NP PP.initial_location
# NP V NP PP.destination
# NP V NP PP.initial_location PP.destination
# NP V NP PP.destination PP.initial_location
# NP V NP
# NP V NP PP.instrument
# NP.instrument V NP
# NP V NP
# NP V NP PP.destinations
# NP V NP PP.initial_location
# NP V NP PP.initial_location PP.destination
# NP V NP ADVP
# NP V NP
# NP V NP PP
# NP V NP
# NP V NP PP.source
# NP V NP
# NP V NP PP.location
# NP V NP
# NP V NP PP.value
# NP V NP
# NP V
# NP V PP
# NP V NP
# NP V NP PP.instrument
# NP V NP together
# NP V NP ADJP
# NP V NP ADJP PP.instrument
# NP V NP PP.result
# NP V NP PP.result PP.instrument
# NP V NP PP
# NP.instrument V NP
# NP V NP ADJP
# NP V NP ADJP PP.result
# NP V NP
# NP V NP.patient
# NP V NP PP.instrument
# NP.patient V
# NP V ADV-Middle
# NP.instrument V NP
# NP V NP ADJ
# NP V NP PP.result
# NP V NP PP.result PP.instrument
# NP V NP PP.initial_location
# NP V NP.initial_location
# NP V
# NP V NP ADJP-Result
# NP V NP PP.theme
# NP V NP
# NP V NP up
# NP V up NP
# NP V NP NP
# NP V NP PP.attribute
# NP V NP ADVP
# NP V NP PP.recipient
# NP V NP-Fulfilling PP.theme
# NP V NP
# NP V NP-Fulfilling PP
# NP V NP
# NP V NP PP.instrument
# NP.patient V
# NP V ADV-Middle
# NP.instrument V NP
# NP V NP ADJ
# NP V NP ADJ PP.instrument
# NP V NP PP.result
# NP V NP PP.result PP.instrument
# NP V PP.result
# NP V NP
# NP V NP PP
# NP V NP S_ING
# NP V S_ING
# NP V PP
# NP V NP PP.attribute
# NP V PP.attribute S_ING
# NP V PP.theme S_ING
# NP V NP
# NP V S_ING
# NP V how S
# NP V NP to be NP
# NP V NP ADJ
# NP V S_ING
# NP V NP
# NP V NP PP.recipient
# NP V S_ING
# NP V PP.recipient
# NP V PP.recipient how S
# NP V that S
# NP V NP PP.source
# NP V NP.source
# NP V NP.theme
# NP V NP
# NP V how S
# NP V how S_INF
# NP V
# NP V NP.recipient
# NP V NP.topic
# NP V NP PP.topic
# NP V NP whether S
# NP V NP what S
# NP V NP whether S_INF
# NP V NP what S_INF
# NP V PP.topic whether S
# NP V NP PP.topic what S
# NP V PP.topic whether S_INF
# NP V PP.topic what S_INF
# NP V PP.topic
# NP V PP.recipient how S
# NP V PP.recipient how S_INF
# NP V PP.recipient whether S
# NP V PP.recipient PP.topic what S
# NP V PP.recipient PP.topic what S_INF
# NP V PP.recipient PP.topic whether S_INF
# NP V whether S
# NP V what S
# NP V whether S_INF
# NP V what S_INF
# NP V NP how S
# NP V NP
# NP V S_ING
# NP V NP S_ING
# NP V NP
# NP V NP PP.destination
# NP V NP PP.initial_location
# NP V NP
# NP V NP PP.destination
# NP V NP PP.initial_location
# It V
# It V NP.theme
# It V PP.theme
# NP V NP
# NP V NP PP.theme
# NP V
# NP V that S
# NP V whether/if S
# NP V NP
# NP V NP PP.theme
# NP V NP
# NP V NP PP.goal
# NP V PP.location
# NP V PP.theme
# NP V how S
# NP V how S_INF
# NP V PP.recipient how S
# NP V PP.recipient how S_INF
# NP V what S
# NP V what S_INF
# NP V NP
# NP V NP PP.recipient
# NP V PP.source
# NP V
# NP V S_INF
# NP.theme V
# NP V
# NP V PP.time
# NP V PP.time
# NP V NP
# NP V S-Quote
# NP V NP
# NP V NP ADV
# NP V NP PP.predicate
# NP V NP S_INF
# NP V NP
# NP V NP PP.instrument
# NP V NP PP.theme
# NP V NP
# NP V NP.destination
# NP V NP.theme
# NP V NP PP.destination
# NP V
# NP V
# NP V PP.co-agent
# NP V NP
# NP V NP PP.destination
# NP V NP ADVP
# NP V
# NP V PP.destination
# NP V NP.theme
# NP V NP.theme PP.destination
# NP V NP
# NP V NP
# NP V NP
# NP V
# NP V NP.product PP.material
# NP V NP.material PP.product
# NP V NP PP.beneficiary
# NP V NP.beneficiary NP PP
# NP V NP PP.material PP.beneficiary
# NP V NP PP.beneficiary
# NP V NP PP.product PP.beneficiary
# NP.material V NP
# NP V NP NP PP.asset
# NP V NP PP.material PP.asset
# NP V how S
# NP V NP
# NP V S_ING
# NP V that S
# NP V what S
# NP V
# NP V NP.experiencer
# NP V PP.stimulus
# NP V S_ING
# NP V NP
# NP V S_INF
# NP V PP.destination
# NP V PP.trajectory
# NP V PP.initial_loc PP.destination
# NP V ADV
# NP V PP
# NP V ADV PP
# NP V
# NP V NP
# NP V NP PP.instrument
# NP V NP
# NP V NP PP.theme
# NP V NP
# NP V NP NP
# NP V NP PP.beneficiary
# NP V that S
# NP V NP PP.destination
# NP V NP ADVP
# NP V
# NP V PP.theme
# NP V PP.co-agent PP.theme
# NP V PP.theme S_ING
# NP V PP.co-agent PP.theme S_ING
# NP V
# NP V
# NP V
# NP V
# NP V PP.experiencer
# It V PP.experiencer that S
# It V that S
# That S.stimulus V
# NP V NP
# NP V NP PP.instrument
# NP V
# NP V PP.stimulus
# NP V PP.stimulus S_ING
# NP V PP.stimulus what S
# NP V NP
# NP V for NP S_INF
# NP V NP
# NP V NP to be ADJ
# NP V NP ADJ
# NP V that S
# NP V S_INF
# NP V how S
# NP V how S_INF
# NP V
# NP V PP.recipient
# NP V PP.topic
# NP V NP
# NP V S-Quote
# NP V NP PP.recipient
# NP V that S
# NP V how S_INF
# NP V S_INF
# NP V PP.recipient that S
# NP V PP.recipient how S_INF
# NP V PP.recipient S_INF
# NP V PP.recipient S_INF
# NP V PP.recipient S-Quote
# NP V NP PP.source
# NP V PP.source
# NP V NP
# NP V NP.theme
# NP V NP
# NP V
# NP V NP ADJ
# NP V NP NP
# NP V NP to be NP
# NP V NP ADJ
# NP V that S
# NP V
# NP.location V
# NP V PP.theme
# NP V NP
# NP V
# NP V PP.stimulus
# NP V NP
# NP V
# NP V NP PP.beneficiary
# NP V PP.theme
# NP V NP.theme
# NP V PP.theme
# NP V NP
# NP V NP
# NP V NP PP.source
# NP V
# NP V PP.theme S
# NP V PP.theme whether/if S
# NP V PP.theme what S
# NP V PP.theme whether S_INF
# NP V PP.theme what S_INF
# NP V PP.theme
# NP V PP.co-agent PP.theme whether S
# NP V PP.co-agent PP.theme what S
# NP V PP.co-agent PP.theme what S_INF
# NP V PP.co-agent PP.theme whether S_INF
# NP V PP.co-agent PP.theme
# NP V what S
# NP V NP PP.destination
# NP V NP ADVP
# NP V PP.destination
# NP V NP PP.initial_location PP.destination
# NP V PP.initial_location PP.destination
# NP V PP.theme
# NP V that S
# NP V NP
# NP V NP PP.source
# NP V NP PP.beneficiary
# NP V NP.beneficiary NP
# NP V NP PP.asset
# NP.asset V NP
# NP V NP PP.source NP.asset
# NP V S_ING
# NP V
# NP V PP.location
# There V NP
# PP.location V NP
# NP.location V NP.theme
# NP V NP S_ING
# NP V NP PP.goal
# NP V how S
# NP V how S_INF
# NP V NP
# NP V whether/if S
# NP V what S
# NP V NP PP.stimulus
# NP V NP S_ING
# NP V NP PP.instrument
# NP V NP
# NP V NP PP.co-patient
# NP V ADV-Middle
# NP V NP PP.beneficiary
# NP V NP PP.location
# NP V NP
# NP V PP.theme
# NP V NP
# NP V NP ADJ
# NP V NP PP.result
# NP V NP PP.instrument
# NP V NP
# NP V NP PP.theme
# NP V
# NP V PP.location
# NP.location V PP.theme
# There V NP PP.location
# PP.location there V NP
# NP V NP.theme
# NP V NP
# NP V that S
# NP V
# NP V PP.co-agent
# NP V PP.co-agent PP.topic
# NP V
# NP V PP.topic PP.co-agent
# NP V PP.topic
# NP V PP.topic
# NP V PP.location
# NP V PP.location PP.theme
# NP V S_INF
# NP V NP
# NP V NP PP.recipient
# NP V NP-Dative NP
# NP V NP
# NP V NP PP.material
# NP V NP PP.beneficiary
# NP V NP PP.attribute
# NP V
# NP V PP.stimulus
# NP V NP.patient PP.extent PP.source PP.goal
# NP V NP.patient NP.extent PP.source PP.goal
# NP V ADJ
# NP V
# NP V PP.location
# There V PP NP
# There V NP PP
# PP.location V NP
# NP V
# NP V PP.theme
# NP V PP.predicate
# NP V PP.theme PP.predicate
# NP V
# There V NP
# NP V PP
# NP V NP.location PP.theme
# NP V NP.location
# NP V NP.recipient
# NP V NP PP.topic
# NP V NP.recipient that S
# NP V NP how S_INF
# NP V NP S-Quote
# NP V NP PP.topic
# NP V NP
# NP V NP PP.attribute
# NP V NP
# NP V S
# NP V NP
# NP V that S
# NP V NP to be NP
# NP V that S
# NP V NP
# NP V S_ING
# NP V PP.goal
# NP V NP
# NP V PP.stimulus
# NP V PP.stimulus how/whether S
# NP V that S
# NP V
# NP V NP
# NP V NP PP.initial_location
# NP V PP.result
# NP V NP PP
# NP V NP PP.attribute
# NP V NP
# NP V
# NP V PP.source
# NP V NP
# NP V
# NP V PP.source
# NP V
# NP V NP
# NP V NP PP.destination
# NP V together
# NP V NP S
# NP V NP S-INF
# NP V NP
# NP V PP
# NP V PP
# NP V NP
# NP V NP PP.theme
# NP V NP PP.theme whether S
# NP V NP PP.theme what S
# NP V NP PP.theme whether S_INF
# NP V NP PP.theme what S_INF
# NP V NP S_ING
# NP V NP S_ING
# NP V NP PP.co-theme
# NP V NP PP.co-theme
# NP V NP PP.co-theme
# NP V NP.theme PP
# NP V S_ING
# NP V how S_INF
# NP V NP to be NP
# NP V NP
# NP.location V
# NP V PP.location
# NP V S_INF
# NP V PP.co-patient
# NP V PP.destination
# NP V ADVP
# NP V ADV-Middle
# NP V S_ING
# NP V S_ING
# NP V NP
# NP V PP
# NP V NP PP.asset
# NP V NP PP.recipient PP.asset
# NP V NP NP PP.asset
# NP V
# NP V NP
# NP V how S
# NP V how S_INF
# NP V PP.theme S_ING
# NP V PP.source how S
# NP V PP.source how S_INF
# NP V PP.source PP.theme whether/if S
# NP V PP.source PP.theme what S
# NP V PP.source PP.theme what S_INF
# NP V PP.source PP.theme whether S_INF
# NP V that S
# NP V what S_INF
# NP V NP
# NP V PP.experiencer
# NP V PP.experiencer
# NP V
# NP.patient V NP.extent PP.source PP.goal
# NP.patient V PP.extent PP.source PP.goal
# NP.attribute V NP.extent PP.source PP.goal
# NP.attribute V PP.extent PP.source PP.goal
# NP.patient V PP.attribute NP.extent PP.source PP.goal
# NP.patient V PP.attribute PP.extent PP.source PP.goal
# NP V
# NP V PP.topic
# NP V PP.theme S_ING
# NP V PP.topic what S
# NP V PP.topic what S_INF
# NP V NP
# NP V S
# NP V PP.recipient
# NP V NP PP.recipient
# NP V NP PP.theme
# NP V that S
# NP V PP that S
# NP V S
# NP V NP
# NP V NP NP
# NP V NP together
# NP V PP.attribute
# NP V NP
# NP V PP.attribute
# NP V NP PP.destination
# NP V
# NP V
# NP V PP.destination
# NP V NP PP.destination-Conative
# NP V NP S
# NP V
# NP V NP
# NP V
# NP V PP-Conative
# NP V PP.patient
# NP V NP
# NP V
# NP V PP.patient
# NP V S_INF
# NP V NP
# NP V how S
# NP V NP to be ADJ
# NP V that S
# NP V what S
# NP V NP
# NP V NP PP.theme
# NP V NP S_ING
# NP V NP S_INF
# NP V S_ING
# NP V PP.beneficiary
# NP V PP.beneficiary PP.theme
# NP V NP NP PP
# NP V NP PP.co-patient
# NP V NP
# NP V PP.co-patient
# NP V NP PP.co-patient
# NP V NP
# NP V PP
# NP V NP
# NP V NP
# NP V NP.beneficiary NP
# NP V NP PP.beneficiary
# NP V NP
# NP V NP.beneficiary NP
# NP V NP PP.beneficiary
# NP V NP
# NP V NP ADJP-Result
# NP V PP-Conative
# NP V NP
# NP V NP PP.value
# NP V NP PP.value
# NP V PP.result
# NP V PP.material PP.result
# NP V PP.result  PP.material
# NP V NP-dative NP
# NP V PP.cause
# NP V NP
# There V PP NP
# NP V NP PP.goal S_ING
# NP V NP
# NP V PP
# NP V NP ADJ
# NP V NP
# NP V NP PP
# NP V PP
# NP V
# NP V NP.material PP.product
# NP V NP PP.source
# NP V NP S_INF
# NP V S_ING
# NP V that S
# NP V S_ING
# NP V NP PP
# NP V PP
# NP V PP
# NP V PP PP
# NP V NP PP.co-patient
# NP V NP together
# NP V NP PP
# NP V NP together
# NP V S_INF
# NP V NP
# NP V NP PP.initial_location
# NP V NP PP.destination
# NP V NP PP.initial_location PP.destination
# NP V NP PP.destination PP.initial_location
# NP V
# NP V PP.source
# NP V PP.source S_ING
# NP V
# NP V PP.source
# NP V PP.source S_ING
# NP V
# NP V PP.source
# NP V NP S_ING
# NP V NP
# NP V NP S_ING
# NP V NP PP.goal
# NP V PP.co-patient
# NP V PP.co-patient
# NP V PP.co-agent
# NP V
# NP V NP
# NP V
# NP V PP.co-agent
# NP V
# NP V NP
# NP V
# NP V ADV-Middle
# NP V NP
# NP V NP PP.initial_location
# NP V NP PP.destination
# NP V NP PP.initial_location PP.destination
# NP V NP PP.destination PP.initial_location
# NP V NP PP.goal
# NP V NP PP.theme
# NP V NP
# NP V NP PP.instrument
# NP V ADVP-Middle
# NP.instrument V NP
# NP.instrument V ADVP
# NP V NP
# NP V NP PP.instrument
# NP V ADVP-Middle
# NP.instrument V NP
# NP.instrument V ADVP
# NP V
# NP V PP.theme
# NP V PP.theme
# NP V NP NP
# NP V
# NP V NP
# NP V NP
# NP V NP
# NP V NP-Dative NP
# NP V NP-Dative NP
# NP V
# NP V PP
# NP V NP PP.asset
# NP.asset V NP
# NP V NP ADV
# NP V NP PP.location
# NP V PP
# NP V PP PP
# NP V for NP S_INF
# NP V S_ING
# NP V NP ADJ
# NP V NP ADV
# NP V S_ING
# NP V NP ADJ
# NP V NP S_ING
# NP V S_INF
# NP V NP PP.destination
# NP V NP NP PP.theme
# NP V NP NP
# NP V NP
# NP V PP.recipient
# NP V NP.recipient
# NP V PP.location
# There V NP PP
# PP.location V NP
# PP.location V PP.theme
# NP V PP.location
# There V NP PP
# NP V how S
# NP V what S
# NP V PP-Conative
# NP V
# NP.theme V PP.source
# NP V PP.location
# NP.location V PP.theme
# PP.location V NP
# There V NP PP
# NP V out
# NP V NP
# NP V NP
# NP V PP.stimulus what S
# NP V what S
# NP V PP.stimulus how/whether S
# NP V NP PP.attribute
# NP V NP PP.theme PP.attribute
# NP V NP PP.attribute PP.theme
# NP V NP
# NP V NP-Dative NP
# NP V NP.topic
# NP V NP PP.recipient
# NP V PP.recipient S-Quote
# NP V how S
# NP V how S_INF
# NP V what S_INF
# NP V what S
# NP.instrument V NP
# NP V NP PP.theme
# NP V PP.destination
# NP V
# NP V ADVP
# NP V NP
# NP V NP PP.instrument
# NP V NP P.asset
# NP.asset V NP
# NP.asset V NP NP
# NP.asset V PP
# NP.asset V NP PP
# NP V
# NP V PP.initial_loc
# NP V
# NP V PP.theme S_ING
# NP V PP.theme
# NP V
# NP V NP
# NP V PP.theme S_ING
# NP V
# NP V NP PP.theme
# NP V NP
# NP V PP.co-theme
# NP V NP
# NP V PP.destination NP
# NP V PP.source
# NP V NP
# NP V NP PP.instrument
# NP V PP.theme
# NP V PP.co-agent PP.theme
# NP V PP.theme
# NP V PP.co-agent PP.theme
# NP V PP.theme S_ING
# NP V PP.theme
# NP V PP.theme S_ING
# NP V PP.theme
# NP V PP.co-agent PP.theme
# NP V PP.theme S_ING
# NP V PP.co-agent PP.theme S_ING
# NP V S_ING
# NP V NP
# NP V PP
# NP V NP PP.attribute
# NP V NP to be NP
# NP V that S
# NP V NP ADJ
# NP V NP NP
# NP V NP to be NP
# NP V NP ADJ
# NP V that S
# NP V NP PP.co-patient
# NP V NP
# NP V NP NP together
# NP V PP.co-patient
# NP V ADVP-Middle PP
# NP V ADVP-Middle
# NP NP V ADVP-Middle together
# NP V NP PP.co-patient
# NP V NP
# NP V NP together
# NP V ADVP-Middle PP
# NP V ADVP-Middle
# NP V ADVP-Middle
# NP V
# NP V that S
# NP V what S
# NP V PP.source how S
# NP V PP.source wh-S_INF
# NP.theme V
# NP V ADJ-Middle
# NP V S
# NP V what S
# NP V NP ADJ
# NP V how S
# NP V how S_INF
# NP V NP.beneficiary NP
# NP V NP PP.instrument
# NP V PP.co-agent how S
# NP V PP.co-agent how S_INF
# NP V what S_INF
# NP V NP
# NP V NP-ATTR-POS
# NP V how S
# NP V what S
# NP V NP PP.source
# NP V
# NP V PP.topic
# NP V PP.recipient PP.topic
# NP V PP.topic
# NP V PP.topic S_ING
# NP V PP.recipient that S
# NP V PP.recipient whether/if S
# NP V PP.recipient what S
# NP V PP.recipient how S
# NP V NP ADJ
# NP V
# NP V PP.beneficiary
# NP V PP.location
# NP V
# NP V how S
# NP V how S_INF
# NP V NP
# NP V NP PP.co-agent
# NP V NP PP.theme
# NP V S_ING
# NP V
# NP V NP
# NP V
# NP V NP
# NP V
# NP.patient V NP.extent PP.source PP.goal
# NP.patient V PP.extent PP.source PP.goal
# NP.attribute V NP.extent PP.source PP.goal
# NP.attribute V PP.extent PP.source PP.goal
# NP.patient V PP.attribute NP.extent PP.source PP.goal
# NP.patient V PP.attribute PP.extent PP.source PP.goal
# NP V PP.attribute
# NP V NP
# NP V NP PP.location
# NP V NP PP.location
# NP V NP
# NP V NP
# NP V NP PP.result
# It V that S
# NP V ADV
# NP V PP.topic
# NP V that S
# NP V how S_INF
# NP V S-Quote
# NP V NP
# NP V NP up
# NP V NP down
# NP V NP
# NP V down NP
# NP V NP S_ING
# NP V S_ING
# NP V NP
# NP V S
# NP V
# NP V PP.source PP.goal
# NP V NP
# NP V NP PP.result
# NP V NP to be NP
# NP V NP PP.theme
# NP V NP PP.theme
# NP V
# NP V S_ING
# NP V what S
# NP V what S_INF
# NP V NP ADJ
# NP V whether/if S
# NP V what S
# NP V what S_INF
# NP V
# NP V PP.theme S_ING
# NP V PP.theme what S
# NP V PP.theme
# NP V PP.theme PP.source
# NP V NP
# NP V S_ING
# NP V
# NP V NP
# NP V PP.attribute
# NP V PP.destination
# NP.theme V NP
# NP V PP.theme
# NP V
# NP V
# NP V NP PP.co-patient
# NP V
# NP V PP
# NP V PP.trajectory
# NP V NP.value
# NP V PP
# NP V
# NP V PP ADV-Middle
# NP V NP
# NP V NP
# NP V NP-Dative NP
# NP V NP that S
# NP V
# NP V NP PP.result
# NP V PP.result NP
# NP V NP S_INF
# NP V NP to be ADJ
# NP.theme V NP
# NP.location V PP.theme
# NP V NP.source
# NP V NP.recipient
# NP V NP S_INF
# NP V NP S_ING
# NP V NP S
# NP V NP what S
# NP V NP what S_INF
# NP V NP how S
# NP V that S
# NP V that S
# NP V NP PP.recipient
# NP V PP.recipient how S
# NP V PP.recipient how S_INF
# NP V PP.recipient that S
# NP V PP.recipient that S
# NP V PP.recipient what S
# NP V PP.recipient what S_INF
# NP V NP
# NP V NP
# NP V NP
# NP V S_INF
# NP V NP
# NP V PP.theme S_ING
# NP V NP PP.source
# NP V NP
# NP V NP ADJ
# NP V whether/if S
# NP V what S
# NP V what S_INF
# NP V
# NP NP V together
# NP V PP.patient
# NP V
# NP V together
# NP V PP.topic
# NP V S_ING
# NP V what S_INF
# NP V how S
# NP V whether/if S
# NP V whether S_INF
# NP V S
# NP V S_ING
# NP V S_ING
# NP V PP.topic S_ING
# NP V NP to be NP
# NP V NP
# NP.theme V
# NP V NP
# NP V PP.instrument
# NP V NP PP.instrument
# NP.instrument V NP
# NP V NP.beneficiary NP
# NP V NP
# NP V NP
# NP V PP.theme
# NP V PP.predicate
# NP V
# NP V NP
# NP V NP S_ING
# NP V NP PP.goal
# NP V PP.stimulus
# NP V PP.stimulus S_ING
# NP V PP.stimulus what S
# NP V PP.stimulus what S
# NP V NP PP.attribute
# NP V S_INF
# NP V
# NP V NP PP.recipient
# NP V PP.recipient how S
# NP V PP.recipient how S_INF
# NP V PP.recipient that S
# NP V PP.recipient that S
# NP V PP.recipient what S
# NP V PP.recipient what S_INF
# NP V PP.theme S_ING
# NP V S_INF
# NP V S_ING
# NP V NP ADJ
# NP V NP NP
# NP V NP PP.attribute
# NP V whether S_INF
# NP V how S_INF
# NP V whether/if S
# NP V whether/if S_INF
# NP V S_ING
# NP V PP.stimulus

# %%
# Get all frame types by querying db
frame_types = []
frame_type_count_dict = OrderedDict()
for doc in list(db.verbnet.find({}, {'frames.description':1, '_id':0})):
    for frame in doc['frames']:
        frame_types_list = frame['description']['primary']
        frame_types.append(frame_types_list)
for f_type in sorted(frame_types):
    frame_type_count_dict[f_type] = frame_type_count_dict.get(f_type, 0) + 1
frame_type_count_dict
# Out:
# OrderedDict([('It V', 1),
#              ('It V NP.theme', 1),
#              ('It V PP.experiencer that S', 1),
#              ('It V PP.theme', 1),
#              ('It V that S', 2),
#              ('NP NP V ADVP-Middle together', 1),
#              ('NP NP V together', 1),
#              ('NP V', 124),
#              ('NP V ADJ', 4),
#              ('NP V ADJ PP.experiencer', 1),
#              ('NP V ADJ-Middle', 1),
#              ('NP V ADJP NP', 1),
#              ('NP V ADV', 4),
#              ('NP V ADV NP', 1),
#              ('NP V ADV PP', 1),
#              ('NP V ADV-Middle', 11),
#              ('NP V ADV-Middle PP', 1),
#              ('NP V ADV-Middle PP.location', 1),
#              ('NP V ADV-Middle together', 1),
#              ('NP V ADVP', 2),
#              ('NP V ADVP-Middle', 8),
#              ('NP V ADVP-Middle PP', 4),
#              ('NP V NP', 233),
#              ('NP V NP ADJ', 21),
#              ('NP V NP ADJ PP.instrument', 1),
#              ('NP V NP ADJP', 10),
#              ('NP V NP ADJP PP.instrument', 3),
#              ('NP V NP ADJP PP.result', 1),
#              ('NP V NP ADJP-Result', 2),
#              ('NP V NP ADV', 4),
#              ('NP V NP ADVP', 8),
#              ('NP V NP NP', 12),
#              ('NP V NP NP PP', 1),
#              ('NP V NP NP PP.asset', 2),
#              ('NP V NP NP PP.theme', 1),
#              ('NP V NP NP together', 1),
#              ('NP V NP NP.asset', 1),
#              ('NP V NP P.asset', 1),
#              ('NP V NP PP', 10),
#              ('NP V NP PP PP', 1),
#              ('NP V NP PP PP.instrument', 1),
#              ('NP V NP PP.asset', 3),
#              ('NP V NP PP.attribute', 20),
#              ('NP V NP PP.attribute PP.theme', 1),
#              ('NP V NP PP.beneficiary', 11),
#              ('NP V NP PP.co-agent', 2),
#              ('NP V NP PP.co-patient', 10),
#              ('NP V NP PP.co-theme', 5),
#              ('NP V NP PP.destination', 23),
#              ('NP V NP PP.destination PP.initial_location', 5),
#              ('NP V NP PP.destination-Conative', 1),
#              ('NP V NP PP.destinations', 1),
#              ('NP V NP PP.goal', 11),
#              ('NP V NP PP.goal S_ING', 1),
#              ('NP V NP PP.initial_location', 12),
#              ('NP V NP PP.initial_location PP.destination', 9),
#              ('NP V NP PP.instrument', 24),
#              ('NP V NP PP.location', 18),
#              ('NP V NP PP.manner', 1),
#              ('NP V NP PP.material', 1),
#              ('NP V NP PP.material PP.asset', 1),
#              ('NP V NP PP.material PP.beneficiary', 1),
#              ('NP V NP PP.patient', 1),
#              ('NP V NP PP.predicate', 1),
#              ('NP V NP PP.product PP.beneficiary', 1),
#              ('NP V NP PP.recipient', 15),
#              ('NP V NP PP.recipient PP.asset', 1),
#              ('NP V NP PP.recipient PP.theme', 1),
#              ('NP V NP PP.result', 22),
#              ('NP V NP PP.result PP.instrument', 7),
#              ('NP V NP PP.source', 17),
#              ('NP V NP PP.source NP.asset', 1),
#              ('NP V NP PP.source PP.beneficiary', 2),
#              ('NP V NP PP.source PP.instrument', 1),
#              ('NP V NP PP.source S', 1),
#              ('NP V NP PP.source S_ING', 1),
#              ('NP V NP PP.source whether S', 1),
#              ('NP V NP PP.stimulus', 1),
#              ('NP V NP PP.theme', 25),
#              ('NP V NP PP.theme PP.attribute', 1),
#              ('NP V NP PP.theme what S', 1),
#              ('NP V NP PP.theme what S_INF', 1),
#              ('NP V NP PP.theme whether S', 1),
#              ('NP V NP PP.theme whether S_INF', 1),
#              ('NP V NP PP.topic', 5),
#              ('NP V NP PP.topic what S', 1),
#              ('NP V NP PP.trajectory', 1),
#              ('NP V NP PP.value', 4),
#              ('NP V NP S', 4),
#              ('NP V NP S-INF', 1),
#              ('NP V NP S-Quote', 1),
#              ('NP V NP S_INF', 8),
#              ('NP V NP S_ING', 22),
#              ('NP V NP apart', 1),
#              ('NP V NP down', 1),
#              ('NP V NP how S', 2),
#              ('NP V NP how S_INF', 1),
#              ('NP V NP that S', 2),
#              ('NP V NP to be ADJ', 4),
#              ('NP V NP to be NP', 10),
#              ('NP V NP together', 7),
#              ('NP V NP up', 2),
#              ('NP V NP what S', 2),
#              ('NP V NP what S_INF', 2),
#              ('NP V NP whether S', 1),
#              ('NP V NP whether S_INF', 1),
#              ('NP V NP-ATTR-POS', 1),
#              ('NP V NP-Dative NP', 8),
#              ('NP V NP-Fulfilling PP', 1),
#              ('NP V NP-Fulfilling PP.theme', 1),
#              ('NP V NP-PRO-ARB', 1),
#              ('NP V NP-dative NP', 1),
#              ('NP V NP.attribute', 2),
#              ('NP V NP.beneficiary NP', 5),
#              ('NP V NP.beneficiary NP PP', 1),
#              ('NP V NP.destination', 4),
#              ('NP V NP.destination PP.theme', 2),
#              ('NP V NP.experiencer', 1),
#              ('NP V NP.initial_location', 2),
#              ('NP V NP.location', 5),
#              ('NP V NP.location PP.theme', 2),
#              ('NP V NP.material', 1),
#              ('NP V NP.material PP.product', 4),
#              ('NP V NP.patient', 4),
#              ('NP V NP.patient NP.extent PP.source PP.goal', 1),
#              ('NP V NP.patient PP.extent PP.source PP.goal', 1),
#              ('NP V NP.patient PP.material PP.result', 1),
#              ('NP V NP.patient PP.result', 1),
#              ('NP V NP.product PP.material', 2),
#              ('NP V NP.recipient', 8),
#              ('NP V NP.recipient PP.topic', 1),
#              ('NP V NP.recipient S', 1),
#              ('NP V NP.recipient S-Quote', 1),
#              ('NP V NP.recipient S_INF', 1),
#              ('NP V NP.recipient that S', 2),
#              ('NP V NP.recipient when S_INF', 1),
#              ('NP V NP.source', 2),
#              ('NP V NP.stimulus', 1),
#              ('NP V NP.theme', 15),
#              ('NP V NP.theme (PP)', 2),
#              ('NP V NP.theme PP', 1),
#              ('NP V NP.theme PP.destination', 2),
#              ('NP V NP.topic', 2),
#              ('NP V NP.value', 2),
#              ('NP V PP', 26),
#              ('NP V PP ADV-Middle', 2),
#              ('NP V PP PP', 7),
#              ('NP V PP that S', 1),
#              ('NP V PP-Conative', 3),
#              ('NP V PP.agent', 1),
#              ('NP V PP.attribute', 6),
#              ('NP V PP.attribute S_ING', 1),
#              ('NP V PP.beneficiary', 4),
#              ('NP V PP.beneficiary PP.theme', 1),
#              ('NP V PP.cause', 1),
#              ('NP V PP.co-agent', 10),
#              ('NP V PP.co-agent PP.goal', 1),
#              ('NP V PP.co-agent PP.theme', 6),
#              ('NP V PP.co-agent PP.theme S_ING', 2),
#              ('NP V PP.co-agent PP.theme what S', 2),
#              ('NP V PP.co-agent PP.theme what S_INF', 2),
#              ('NP V PP.co-agent PP.theme whether S', 2),
#              ('NP V PP.co-agent PP.theme whether S_INF', 2),
#              ('NP V PP.co-agent PP.topic', 3),
#              ('NP V PP.co-agent how S', 1),
#              ('NP V PP.co-agent how S_INF', 1),
#              ('NP V PP.co-patient', 6),
#              ('NP V PP.co-theme', 4),
#              ('NP V PP.destination', 8),
#              ('NP V PP.destination NP', 2),
#              ('NP V PP.experiencer', 4),
#              ('NP V PP.goal', 1),
#              ('NP V PP.goal what S_INF', 1),
#              ('NP V PP.initial_loc', 1),
#              ('NP V PP.initial_loc PP.destination', 1),
#              ('NP V PP.initial_location', 1),
#              ('NP V PP.initial_location PP.destination', 2),
#              ('NP V PP.instrument', 2),
#              ('NP V PP.location', 26),
#              ('NP V PP.location PP.theme', 3),
#              ('NP V PP.material PP.result', 1),
#              ('NP V PP.patient', 5),
#              ('NP V PP.predicate', 2),
#              ('NP V PP.recipient', 10),
#              ('NP V PP.recipient NP', 1),
#              ('NP V PP.recipient PP.topic', 2),
#              ('NP V PP.recipient PP.topic what S', 1),
#              ('NP V PP.recipient PP.topic what S_INF', 1),
#              ('NP V PP.recipient PP.topic whether S_INF', 1),
#              ('NP V PP.recipient S-Quote', 4),
#              ('NP V PP.recipient S_INF', 3),
#              ('NP V PP.recipient how S', 6),
#              ('NP V PP.recipient how S_INF', 5),
#              ('NP V PP.recipient that S', 9),
#              ('NP V PP.recipient what S', 3),
#              ('NP V PP.recipient what S_INF', 2),
#              ('NP V PP.recipient when S_INF', 1),
#              ('NP V PP.recipient whether S', 1),
#              ('NP V PP.recipient whether/if S', 1),
#              ('NP V PP.result', 6),
#              ('NP V PP.result  PP.material', 1),
#              ('NP V PP.result NP', 1),
#              ('NP V PP.result PP.instrument', 1),
#              ('NP V PP.source', 8),
#              ('NP V PP.source PP.goal', 1),
#              ('NP V PP.source PP.theme what S', 1),
#              ('NP V PP.source PP.theme what S_INF', 1),
#              ('NP V PP.source PP.theme whether S_INF', 1),
#              ('NP V PP.source PP.theme whether/if S', 1),
#              ('NP V PP.source S_ING', 2),
#              ('NP V PP.source how S', 2),
#              ('NP V PP.source how S_INF', 1),
#              ('NP V PP.source wh-S_INF', 1),
#              ('NP V PP.stimulus', 10),
#              ('NP V PP.stimulus S_ING', 2),
#              ('NP V PP.stimulus how/whether S', 2),
#              ('NP V PP.stimulus what S', 4),
#              ('NP V PP.theme', 28),
#              ('NP V PP.theme NP S_ING', 1),
#              ('NP V PP.theme NP.location', 1),
#              ('NP V PP.theme PP.location', 1),
#              ('NP V PP.theme PP.predicate', 1),
#              ('NP V PP.theme PP.source', 1),
#              ('NP V PP.theme S', 2),
#              ('NP V PP.theme S_INF', 1),
#              ('NP V PP.theme S_ING', 16),
#              ('NP V PP.theme what S', 3),
#              ('NP V PP.theme what S_INF', 2),
#              ('NP V PP.theme whether S', 1),
#              ('NP V PP.theme whether S_INF', 2),
#              ('NP V PP.theme whether/if S', 1),
#              ('NP V PP.time', 2),
#              ('NP V PP.topic', 12),
#              ('NP V PP.topic NP S_ING', 1),
#              ('NP V PP.topic PP.co-agent', 3),
#              ('NP V PP.topic PP.recipient', 1),
#              ('NP V PP.topic S_ING', 2),
#              ('NP V PP.topic what S', 2),
#              ('NP V PP.topic what S_INF', 3),
#              ('NP V PP.topic whether S', 1),
#              ('NP V PP.topic whether S_INF', 1),
#              ('NP V PP.trajectory', 2),
#              ('NP V PP.trajectory PP.goal', 1),
#              ('NP V PP.value', 1),
#              ('NP V S', 6),
#              ('NP V S-Quote', 4),
#              ('NP V S_INF', 18),
#              ('NP V S_ING', 39),
#              ('NP V apart', 1),
#              ('NP V down NP', 1),
#              ('NP V for NP S_INF', 4),
#              ('NP V how S', 16),
#              ('NP V how S_INF', 13),
#              ('NP V out', 1),
#              ('NP V that S', 30),
#              ('NP V that S PP.theme', 1),
#              ('NP V together', 4),
#              ('NP V together ADV-Middle', 2),
#              ('NP V up NP', 1),
#              ('NP V what S', 17),
#              ('NP V what S_INF', 10),
#              ('NP V when S_INF', 1),
#              ('NP V whether S', 1),
#              ('NP V whether S_INF', 3),
#              ('NP V whether/if S', 6),
#              ('NP V whether/if S_INF', 1),
#              ('NP V why S', 1),
#              ('NP.agent V', 1),
#              ('NP.agent V NP', 1),
#              ('NP.asset V NP', 3),
#              ('NP.asset V NP NP', 1),
#              ('NP.asset V NP PP', 1),
#              ('NP.asset V PP', 1),
#              ('NP.attribute V', 1),
#              ('NP.attribute V NP.extent PP.source PP.goal', 2),
#              ('NP.attribute V PP.extent PP.source PP.goal', 2),
#              ('NP.cause V NP', 1),
#              ('NP.instrument V ADVP', 3),
#              ('NP.instrument V NP', 12),
#              ('NP.location V', 2),
#              ('NP.location V NP', 2),
#              ('NP.location V NP.theme', 1),
#              ('NP.location V PP.agent', 1),
#              ('NP.location V PP.theme', 5),
#              ('NP.material V NP', 1),
#              ('NP.material V PP.product', 2),
#              ('NP.patient V', 5),
#              ('NP.patient V NP.extent PP.source PP.goal', 2),
#              ('NP.patient V PP.attribute', 1),
#              ('NP.patient V PP.attribute NP.extent PP.source PP.goal', 2),
#              ('NP.patient V PP.attribute PP.extent PP.source PP.goal', 2),
#              ('NP.patient V PP.extent PP.source PP.goal', 2),
#              ('NP.patient V PP.material PP.result', 1),
#              ('NP.patient V PP.result', 1),
#              ('NP.product V PP.material', 1),
#              ('NP.theme V', 7),
#              ('NP.theme V NP', 2),
#              ('NP.theme V PP.location', 1),
#              ('NP.theme V PP.source', 1),
#              ('PP.location V NP', 9),
#              ('PP.location V PP.theme', 1),
#              ('PP.location there V NP', 1),
#              ('Passive', 1),
#              ('That S.stimulus V', 1),
#              ('There V NP', 4),
#              ('There V NP PP', 7),
#              ('There V NP PP.location', 1),
#              ('There V PP NP', 4)])

# %%
np_themroles = {}
# np_themrole_count_dict = OrderedDict()
for frame in db.verbnet.find({}, {'frames.syntax':1, 'class_id': 1, '_id':0}):
    for syn_list in frame['frames']:
        for arg in syn_list['syntax']:
            if arg['arg_type']=='NP':
                if "?" in arg['value']:
                    print(arg['value'], syn_list['syntax'])
                if arg['value'] not in np_themroles:
                    ## Some roles have a ? mark at the start. Replace them with a "".
                    np_themroles[arg['value'].replace("?", "")] = {'count':1, 'vn_class_members':set([frame['class_id']])}
                else:
                    np_themroles[arg['value'].replace("?", "")]['count'] += 1
                    np_themroles[arg['value'].replace("?", "")]['vn_class_members'].add(frame['class_id'].replace("?", ""))
np_themroles.keys()
# Out:
# ?Extent [{'arg_type': 'NP', 'value': 'Causer', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Source [{'arg_type': 'NP', 'value': 'Causer', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Goal [{'arg_type': 'NP', 'value': 'Causer', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Extent [{'arg_type': 'NP', 'value': 'Causer', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Source [{'arg_type': 'NP', 'value': 'Causer', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Goal [{'arg_type': 'NP', 'value': 'Causer', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Initial_State [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Result [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Initial_State [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Result [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Initial_State [{'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': 'of', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Result [{'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': 'of', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Initial_State [{'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': 'of', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Result [{'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': 'of', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Extent [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Initial_State [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Result [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Extent [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Initial_State [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Result [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Initial_State', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Result', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Source [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Goal [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Extent [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': '?by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Source [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': '?by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Goal [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': '?by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Extent [{'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': 'of', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Source [{'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': 'of', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Goal [{'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': 'of', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Source [{'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': 'of', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Goal [{'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': 'of', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Extent [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Source [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Goal [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Extent [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Source [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# ?Goal [{'arg_type': 'NP', 'value': 'Patient', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'VERB', 'value': 'VERB', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'PREP', 'value': 'in', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': 'Attribute', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?by', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Extent', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?from', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Source', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}, {'arg_type': 'PREP', 'value': '?to', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': '&'}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': None}}, {'arg_type': 'NP', 'value': '?Goal', 'selrestrs': {'selrestr_list': None, 'selrestr_logic': None}, 'synrestrs': {'synrestr_list': None, 'synrestr_logic': '&'}}]
# dict_keys(['Agent', 'Result', 'Theme', 'Attribute', 'Trajectory', 'Location', 'Patient', 'Causer', 'Source', 'Predicate', 'Co-Agent', 'Topic', 'Experiencer', 'Stimulus', 'Recipient', 'Instrument', 'Goal', 'Co-Patient', 'Destination', 'Beneficiary', 'Product', 'Value', 'Pivot', 'Co-Theme', 'Initial_Location', 'Reflexive', 'Asset', 'Context', 'Initial_State', 'Duration', 'Path', 'Material', 'Time', 'Precondition', 'Affector', 'Extent', 'Manner'])

# %%
### Find selectional restrictions and add member vn classes to respective restrictions as the main dict elements so that its easy for html to parse
from pprint import pprint as pp
sr_dict = {}
for vn_class in list(db.verbnet.find({'frames.syntax.synrestrs.synrestr_list.type': {'$exists':1}}, {'frames.syntax.synrestrs.synrestr_list':1, 'class_id':1, '_id':0})):
    for syn in vn_class['frames']:
        for el in syn['syntax']:
            if el['synrestrs']['synrestr_list']:
                for sr_el in el['synrestrs']['synrestr_list']:
                    if sr_el['value']=='-':
                        print(sr_el['type'])
                    if sr_el['type'] not in sr_dict:
                        sr_dict[sr_el['type']] = {'Frames':{sr_el['value']:{'count':1,
                                                                            'vn_mem':set([vn_class['class_id']])}}}
                    else:
                        if sr_el['value'] not in sr_dict[sr_el['type']]['Frames']:
                            sr_dict[sr_el['type']]['Frames'][sr_el['value']] = {'count':1,
                                                                                 'vn_mem': set([vn_class['class_id']])}                          
                        else:
                            sr_dict[sr_el['type']]['Frames'][sr_el['value']]['count'] +=1
                            sr_dict[sr_el['type']]['Frames'][sr_el['value']]['vn_mem'].add(vn_class['class_id'])
for vn_class in list(db.verbnet.find({}, {'themroles.selrestrs.selrestrs_list':1, 'class_id':1, '_id':0})):
    for selres in vn_class['themroles']:
        if isinstance(selres['selrestrs']['selrestrs_list'], list):
            for sel_elem in selres['selrestrs']['selrestrs_list']:
                if sel_elem['type']:
                    if sel_elem['type'] not in sr_dict:
                        sr_dict[sel_elem['type']] = {'Themroles': {sel_elem['value']:{'count':1, 
                                                                'vn_mem': set([vn_class['class_id']])}}}
                    elif 'Themroles' not in sr_dict[sel_elem['type']]:
                        sr_dict[sel_elem['type']]['Themroles'] = {sel_elem['value']:{'count':1,
                                                                                     'vn_mem': set([vn_class['class_id']])}}
                    else:
                        if sel_elem['value'] not in sr_dict[sel_elem['type']]['Themroles']:
                            sr_dict[sel_elem['type']]['Themroles'][sel_elem['value']] = {'count':1,'vn_mem': set([vn_class['class_id']])}
                        else:
                            sr_dict[sel_elem['type']]['Themroles'][sel_elem['value']]['count'] +=1
                            sr_dict[sel_elem['type']]['Themroles'][sel_elem['value']]['vn_mem'].add(vn_class['class_id'])
# Out:
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# definite
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# definite
# sentential
# sentential
# sentential
# definite
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# definite
# sentential
# sentential
# sentential
# definite
# definite
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# definite
# definite
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# tensed_that
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# sentential
# tensed_that
# sentential
# tensed_that
# sentential
# sentential
# sentential
# sentential
# sentential
# tensed_that
# sentential
# sentential
# sentential
